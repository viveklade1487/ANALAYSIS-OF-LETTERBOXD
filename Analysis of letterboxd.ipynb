# %% [markdown]
# # Analysis of Letterboxd

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('ticks')
sns.set_palette('bright')
sns.set_context('notebook', font_scale=1.2)
pd.options.plotting.backend = "plotly"

# %%
animation = pd.read_csv('Animation.csv')
horror = pd.read_csv('Horror.csv')
scifi = pd.read_csv('SciFi.csv')
thriller = pd.read_csv('Thriller.csv')

# %% [markdown]
# ## Data cleanup

# %%
animation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8123 entries, 0 to 8122
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            8123 non-null   object
#  1   year             8117 non-null   float64
#  2   director         7909 non-null   object
#  3   running_time     8123 non-null   int64
#  4   views            8123 non-null   int64
#  5   likes            8123 non-null   int64
#  6   avg_rating       8123 non-null   float64
#  7   half_star        8123 non-null   int64
#  8   one_star         8123 non-null   int64
#  9   one_half_star    8123 non-null   int64
#  10  two_star         8123 non-null   int64
#  11  two_half_star    8123 non-null   int64
#  12  three_star       8123 non-null   int64
#  13  three_half_star  8123 non-null   int64
#  14  four_star        8123 non-null   int64
#  15  four_half_star   8123 non-null   int64
#  16  five_star        8123 non-null   int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 1.1+ MB

# %%
animation.describe(include='all')
# Out:
#              title         year     director  running_time          views  \
# count         8123  8117.000000         7909   8123.000000    8123.000000
# unique        7996          NaN         3630           NaN            NaN
# top     Cinderella          NaN  Chuck Jones           NaN            NaN
# freq             5          NaN          211           NaN            NaN
# mean           NaN  1987.235555          NaN     40.215807    5574.548320
# std            NaN    29.929833          NaN     52.810033   32810.409398
# min            NaN  1885.000000          NaN      1.000000      35.000000
# 25%            NaN  1961.000000          NaN      7.000000     110.500000
# 50%            NaN  2000.000000          NaN     13.000000     231.000000
# 75%            NaN  2013.000000          NaN     75.500000     740.000000
# max            NaN  2020.000000          NaN    897.000000  561682.000000
#
#                 likes   avg_rating     half_star      one_star  one_half_star  \
# count     8123.000000  8123.000000   8123.000000   8123.000000    8123.000000
# unique            NaN          NaN           NaN           NaN            NaN
# top               NaN          NaN           NaN           NaN            NaN
# freq              NaN          NaN           NaN           NaN            NaN
# mean      1029.206205     3.219993     26.816078     53.858180      49.394189
# std       7866.939311     0.383906    225.141093    329.424902     271.258463
# min          0.000000     0.900000      0.000000      0.000000       0.000000
# 25%         13.000000     3.000000      0.000000      1.000000       1.000000
# 50%         31.000000     3.300000      1.000000      3.000000       3.000000
# 75%        108.000000     3.400000      5.000000      9.000000       9.000000
# max     232066.000000     4.600000  12506.000000  10294.000000    6896.000000
#
#             two_star  two_half_star    three_star  three_half_star  \
# count    8123.000000    8123.000000   8123.000000      8123.000000
# unique           NaN            NaN           NaN              NaN
# top              NaN            NaN           NaN              NaN
# freq             NaN            NaN           NaN              NaN
# mean      159.230703     178.719685    494.971808       418.605441
# std       830.414109     872.042594   2608.639808      2390.891234
# min         0.000000       0.000000      0.000000         0.000000
# 25%         4.000000       6.000000     13.000000         8.000000
# 50%         9.000000      12.000000     28.000000        19.000000
# 75%        25.000000      34.000000     83.000000        64.000000
# max     16922.000000   15504.000000  47174.000000     45027.000000
#
#            four_star  four_half_star      five_star
# count    8123.000000     8123.000000    8123.000000
# unique           NaN             NaN            NaN
# top              NaN             NaN            NaN
# freq             NaN             NaN            NaN
# mean      614.074726      218.986458     358.851286
# std      4489.385820     1976.451042    3718.157477
# min         0.000000        0.000000       0.000000
# 25%         6.000000        1.000000       2.000000
# 50%        17.000000        4.000000       6.000000
# 75%        60.000000       16.000000      24.000000
# max     95365.000000    71034.000000  151015.000000

# %%
horror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11052 entries, 0 to 11051
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            11052 non-null  object
#  1   year             11046 non-null  float64
#  2   director         10976 non-null  object
#  3   running_time     11052 non-null  int64
#  4   views            11052 non-null  int64
#  5   likes            11052 non-null  int64
#  6   avg_rating       11052 non-null  float64
#  7   half_star        11052 non-null  int64
#  8   one_star         11052 non-null  int64
#  9   one_half_star    11052 non-null  int64
#  10  two_star         11052 non-null  int64
#  11  two_half_star    11052 non-null  int64
#  12  three_star       11052 non-null  int64
#  13  three_half_star  11052 non-null  int64
#  14  four_star        11052 non-null  int64
#  15  four_half_star   11052 non-null  int64
#  16  five_star        11052 non-null  int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 1.4+ MB

# %%
horror.describe(include='all')
# Out:
#                           title          year        director  running_time  \
# count                     11052  11046.000000           10976  11052.000000
# unique                    10339           NaN            6826           NaN
# top     Dr. Jekyll and Mr. Hyde           NaN  David DeCoteau           NaN
# freq                          8           NaN              48           NaN
# mean                        NaN   1997.829712             NaN     83.197883
# std                         NaN     20.641835             NaN     28.903248
# min                         NaN   1895.000000             NaN      1.000000
# 25%                         NaN   1986.000000             NaN     80.000000
# 50%                         NaN   2006.000000             NaN     89.000000
# 75%                         NaN   2014.000000             NaN     95.000000
# max                         NaN   2020.000000             NaN    608.000000
#
#                 views          likes    avg_rating     half_star  \
# count    11052.000000   11052.000000  11052.000000  11052.000000
# unique            NaN            NaN           NaN           NaN
# top               NaN            NaN           NaN           NaN
# freq              NaN            NaN           NaN           NaN
# mean      4344.529406     823.853782      2.810062     52.435215
# std      22098.558663    6153.743060      0.461166    237.354295
# min         34.000000       0.000000      0.900000      0.000000
# 25%        104.000000      10.000000      2.500000      2.000000
# 50%        277.000000      31.000000      2.800000      7.000000
# 75%       1110.250000     148.000000      3.100000     22.000000
# max     605132.000000  261668.000000      4.300000  10250.000000
#
#             one_star  one_half_star      two_star  two_half_star  \
# count   11052.000000   11052.000000  11052.000000   11052.000000
# unique           NaN            NaN           NaN            NaN
# top              NaN            NaN           NaN            NaN
# freq             NaN            NaN           NaN            NaN
# mean       99.525606      93.569399    234.609482     241.492038
# std       394.178772     345.956247    888.161944     899.024736
# min         0.000000       0.000000      0.000000       0.000000
# 25%         5.000000       5.000000      9.000000       8.000000
# 50%        13.000000      13.000000     25.000000      24.000000
# 75%        40.000000      41.000000     93.000000      96.000000
# max      9849.000000    6513.000000  18043.000000   20637.000000
#
#           three_star  three_half_star      four_star  four_half_star  \
# count   11052.000000     11052.000000   11052.000000    11052.000000
# unique           NaN              NaN            NaN             NaN
# top              NaN              NaN            NaN             NaN
# freq             NaN              NaN            NaN             NaN
# mean      511.017101       422.037821     507.563156      169.017644
# std      2229.331836      2211.361403    3773.986745     1676.276906
# min         0.000000         0.000000       0.000000        0.000000
# 25%        11.000000         5.000000       3.000000        0.000000
# 50%        33.000000        17.000000      11.000000        2.000000
# 75%       157.000000        90.000000      61.000000       12.000000
# max     57592.000000     55535.000000  136842.000000    65726.000000
#
#             five_star
# count    11052.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean       214.110297
# std       2646.450847
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%         14.000000
# max     123437.000000

# %%
scifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5827 entries, 0 to 5826
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            5827 non-null   object
#  1   year             5823 non-null   float64
#  2   director         5779 non-null   object
#  3   running_time     5827 non-null   int64
#  4   views            5827 non-null   int64
#  5   likes            5827 non-null   int64
#  6   avg_rating       5827 non-null   float64
#  7   half_star        5827 non-null   int64
#  8   one_star         5827 non-null   int64
#  9   one_half_star    5827 non-null   int64
#  10  two_star         5827 non-null   int64
#  11  two_half_star    5827 non-null   int64
#  12  three_star       5827 non-null   int64
#  13  three_half_star  5827 non-null   int64
#  14  four_star        5827 non-null   int64
#  15  four_half_star   5827 non-null   int64
#  16  five_star        5827 non-null   int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 774.0+ KB

# %%
scifi.describe(include='all')
# Out:
#                title         year      director  running_time          views  \
# count           5827  5823.000000          5779   5827.000000    5827.000000
# unique          5640          NaN          3947           NaN            NaN
# top     Frankenstein          NaN  Ishirō Honda           NaN            NaN
# freq               8          NaN            24           NaN            NaN
# mean             NaN  1996.500429           NaN     85.318002   12432.362966
# std              NaN    20.592035           NaN     37.434474   53452.425040
# min              NaN  1895.000000           NaN      1.000000      35.000000
# 25%              NaN  1985.000000           NaN     78.000000     119.000000
# 50%              NaN  2003.000000           NaN     90.000000     333.000000
# 75%              NaN  2013.000000           NaN    100.000000    1831.000000
# max              NaN  2020.000000           NaN    850.000000  719791.000000
#
#                 likes   avg_rating     half_star      one_star  one_half_star  \
# count     5827.000000  5827.000000   5827.000000   5827.000000    5827.000000
# unique            NaN          NaN           NaN           NaN            NaN
# top               NaN          NaN           NaN           NaN            NaN
# freq              NaN          NaN           NaN           NaN            NaN
# mean      2469.437275     2.898387    109.180196    229.080316     206.881414
# std      14479.067824     0.511744    617.083835   1102.621337     881.745149
# min          0.000000     0.900000      0.000000      0.000000       0.000000
# 25%         13.000000     2.600000      1.000000      4.000000       4.000000
# 50%         42.000000     2.900000      6.000000     12.000000      12.000000
# 75%        239.500000     3.300000     25.000000     52.000000      55.000000
# max     260768.000000     4.400000  26627.000000  41716.000000   25062.000000
#
#             two_star  two_half_star    three_star  three_half_star  \
# count    5827.000000    5827.000000   5827.000000      5827.000000
# unique           NaN            NaN           NaN              NaN
# top              NaN            NaN           NaN              NaN
# freq             NaN            NaN           NaN              NaN
# mean      579.137635     575.518277   1329.661919      1058.524455
# std      2359.063044    2210.382857   5530.382149      4705.722622
# min         0.000000       0.000000      0.000000         0.000000
# 25%         9.000000       8.000000     13.000000         6.000000
# 50%        26.000000      24.000000     38.000000        21.000000
# 75%       123.500000     137.000000    237.000000       141.000000
# max     49076.000000   32039.000000  71584.000000     63621.000000
#
#             four_star  four_half_star      five_star
# count     5827.000000     5827.000000    5827.000000
# unique            NaN             NaN            NaN
# top               NaN             NaN            NaN
# freq              NaN             NaN            NaN
# mean      1426.026944      499.093015     740.281105
# std       8070.482505     3499.584214    6229.123148
# min          0.000000        0.000000       0.000000
# 25%          4.000000        1.000000       1.000000
# 50%         16.000000        3.000000       5.000000
# 75%        110.000000       23.000000      31.000000
# max     129365.000000    70990.000000  150869.000000

# %%
thriller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12836 entries, 0 to 12835
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            12836 non-null  object
#  1   year             12833 non-null  float64
#  2   director         12802 non-null  object
#  3   running_time     12836 non-null  int64
#  4   views            12836 non-null  int64
#  5   likes            12836 non-null  int64
#  6   avg_rating       12836 non-null  float64
#  7   half_star        12836 non-null  int64
#  8   one_star         12836 non-null  int64
#  9   one_half_star    12836 non-null  int64
#  10  two_star         12836 non-null  int64
#  11  two_half_star    12836 non-null  int64
#  12  three_star       12836 non-null  int64
#  13  three_half_star  12836 non-null  int64
#  14  four_star        12836 non-null  int64
#  15  four_half_star   12836 non-null  int64
#  16  five_star        12836 non-null  int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 1.7+ MB

# %%
thriller.describe(include='all')
# Out:
#           title          year          director  running_time          views  \
# count     12836  12833.000000             12802  12836.000000   12836.000000
# unique    11990           NaN              7668           NaN            NaN
# top     Missing           NaN  Alfred Hitchcock           NaN            NaN
# freq          6           NaN                37           NaN            NaN
# mean        NaN   1998.998831               NaN     98.254986    7473.757089
# std         NaN     20.167857               NaN     25.973443   32415.529590
# min         NaN   1902.000000               NaN      1.000000      33.000000
# 25%         NaN   1989.000000               NaN     88.000000     110.000000
# 50%         NaN   2007.000000               NaN     95.000000     339.000000
# 75%         NaN   2014.000000               NaN    107.000000    1826.000000
# max         NaN   2021.000000               NaN    803.000000  712015.000000
#
#                 likes    avg_rating     half_star      one_star  \
# count    12836.000000  12836.000000  12836.000000  12836.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean      1422.891088      2.938969     54.903007    118.423496
# std       9362.125019      0.447462    281.126271    494.097765
# min          0.000000      0.900000      0.000000      0.000000
# 25%         10.000000      2.700000      1.000000      3.000000
# 50%         35.500000      3.000000      5.000000     10.000000
# 75%        222.000000      3.200000     18.000000     39.000000
# max     286934.000000      4.600000  10251.000000  14296.000000
#
#         one_half_star      two_star  two_half_star    three_star  \
# count    12836.000000  12836.000000   12836.000000  12836.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean       117.293316    328.195700     355.639140    812.383998
# std        432.564697   1148.446012    1172.661312   2939.661636
# min          0.000000      0.000000       0.000000      0.000000
# 25%          4.000000     10.000000      10.000000     14.000000
# 50%         11.000000     27.000000      29.000000     48.000000
# 75%         44.000000    117.000000     139.000000    264.000000
# max       9557.000000  27060.000000   25535.000000  58742.000000
#
#         three_half_star      four_star  four_half_star      five_star
# count      12836.000000   12836.000000    12836.000000   12836.000000
# unique              NaN            NaN             NaN            NaN
# top                 NaN            NaN             NaN            NaN
# freq                NaN            NaN             NaN            NaN
# mean         723.173185     948.507012      357.502805     428.523605
# std         2946.029343    5475.450129     2816.761870    4722.109520
# min            0.000000       0.000000        0.000000       0.000000
# 25%            7.000000       4.000000        0.000000       1.000000
# 50%           28.000000      18.000000        3.000000       4.000000
# 75%          183.000000     129.000000       24.000000      25.000000
# max        53357.000000  136870.000000    90025.000000  243931.000000

# %%
animation.isnull().sum()
# Out:
# title                0
# year                 6
# director           214
# running_time         0
# views                0
# likes                0
# avg_rating           0
# half_star            0
# one_star             0
# one_half_star        0
# two_star             0
# two_half_star        0
# three_star           0
# three_half_star      0
# four_star            0
# four_half_star       0
# five_star            0
# dtype: int64

# %%
100*animation.isnull().sum()/len(animation)
# Out:
# title              0.000000
# year               0.073864
# director           2.634495
# running_time       0.000000
# views              0.000000
# likes              0.000000
# avg_rating         0.000000
# half_star          0.000000
# one_star           0.000000
# one_half_star      0.000000
# two_star           0.000000
# two_half_star      0.000000
# three_star         0.000000
# three_half_star    0.000000
# four_star          0.000000
# four_half_star     0.000000
# five_star          0.000000
# dtype: float64

# %%
animation['director'].nunique()
# Out:
# 3630

# %%
len(animation)
# Out:
# 8123

# %%
animation['year'].nunique()
# Out:
# 120

# %%
animation.dropna(axis=0, inplace=True)

# %%
horror.isnull().sum()
# Out:
# title               0
# year                6
# director           76
# running_time        0
# views               0
# likes               0
# avg_rating          0
# half_star           0
# one_star            0
# one_half_star       0
# two_star            0
# two_half_star       0
# three_star          0
# three_half_star     0
# four_star           0
# four_half_star      0
# five_star           0
# dtype: int64

# %%
100*horror.isnull().sum()/len(horror)
# Out:
# title              0.000000
# year               0.054289
# director           0.687658
# running_time       0.000000
# views              0.000000
# likes              0.000000
# avg_rating         0.000000
# half_star          0.000000
# one_star           0.000000
# one_half_star      0.000000
# two_star           0.000000
# two_half_star      0.000000
# three_star         0.000000
# three_half_star    0.000000
# four_star          0.000000
# four_half_star     0.000000
# five_star          0.000000
# dtype: float64

# %%
horror['director'].nunique()
# Out:
# 6826

# %%
horror.dropna(axis=0, inplace=True)

# %%
scifi.isnull().sum()
# Out:
# title               0
# year                4
# director           48
# running_time        0
# views               0
# likes               0
# avg_rating          0
# half_star           0
# one_star            0
# one_half_star       0
# two_star            0
# two_half_star       0
# three_star          0
# three_half_star     0
# four_star           0
# four_half_star      0
# five_star           0
# dtype: int64

# %%
100*scifi.isnull().sum()/len(scifi)
# Out:
# title              0.000000
# year               0.068646
# director           0.823752
# running_time       0.000000
# views              0.000000
# likes              0.000000
# avg_rating         0.000000
# half_star          0.000000
# one_star           0.000000
# one_half_star      0.000000
# two_star           0.000000
# two_half_star      0.000000
# three_star         0.000000
# three_half_star    0.000000
# four_star          0.000000
# four_half_star     0.000000
# five_star          0.000000
# dtype: float64

# %%
scifi['director'].nunique()
# Out:
# 3947

# %%
scifi.dropna(axis=0, inplace=True)

# %%
thriller.isnull().sum()
# Out:
# title               0
# year                3
# director           34
# running_time        0
# views               0
# likes               0
# avg_rating          0
# half_star           0
# one_star            0
# one_half_star       0
# two_star            0
# two_half_star       0
# three_star          0
# three_half_star     0
# four_star           0
# four_half_star      0
# five_star           0
# dtype: int64

# %%
100*thriller.isnull().sum()/len(thriller)
# Out:
# title              0.000000
# year               0.023372
# director           0.264880
# running_time       0.000000
# views              0.000000
# likes              0.000000
# avg_rating         0.000000
# half_star          0.000000
# one_star           0.000000
# one_half_star      0.000000
# two_star           0.000000
# two_half_star      0.000000
# three_star         0.000000
# three_half_star    0.000000
# four_star          0.000000
# four_half_star     0.000000
# five_star          0.000000
# dtype: float64

# %%
thriller['director'].nunique()
# Out:
# 7668

# %%
thriller.dropna(axis=0, inplace=True)

# %% [markdown]
# ## Data wrangling

# %%
animation = animation[(50 <= animation.running_time) & (animation.running_time <= 240)]

# %%
animation.describe(include='all')
# Out:
#                           title         year         director  running_time  \
# count                      2766  2766.000000             2766   2766.000000
# unique                     2747          NaN             1809           NaN
# top     The Wind in the Willows          NaN  Kunihiko Yuyama           NaN
# freq                          3          NaN               25           NaN
# mean                        NaN  2003.248373              NaN     86.032538
# std                         NaN    14.357013              NaN     21.119423
# min                         NaN  1926.000000              NaN     50.000000
# 25%                         NaN  1996.000000              NaN     74.000000
# 50%                         NaN  2007.000000              NaN     85.000000
# 75%                         NaN  2014.000000              NaN     95.000000
# max                         NaN  2020.000000              NaN    227.000000
#
#                 views          likes   avg_rating     half_star      one_star  \
# count     2766.000000    2766.000000  2766.000000   2766.000000   2766.000000
# unique            NaN            NaN          NaN           NaN           NaN
# top               NaN            NaN          NaN           NaN           NaN
# freq              NaN            NaN          NaN           NaN           NaN
# mean     14910.309834    2774.068691     3.129537     71.213666    145.368402
# std      54872.326052   13281.793063     0.479276    380.219172    551.975774
# min         35.000000       0.000000     0.900000      0.000000      0.000000
# 25%        151.000000      18.000000     2.900000      1.000000      2.000000
# 50%        521.000000      69.500000     3.200000      4.000000      9.000000
# 75%       3124.000000     451.500000     3.400000     23.000000     47.750000
# max     561682.000000  232066.000000     4.500000  12506.000000  10294.000000
#
#         one_half_star      two_star  two_half_star    three_star  \
# count     2766.000000   2766.000000    2766.000000   2766.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean       132.734273    429.454808     474.181490   1311.323572
# std        452.393491   1381.099729    1445.804346   4343.142498
# min          0.000000      0.000000       0.000000      0.000000
# 25%          2.000000      7.000000       8.000000     17.000000
# 50%          9.000000     23.000000      28.000000     59.000000
# 75%         53.000000    142.750000     171.750000    348.750000
# max       6896.000000  16922.000000   15504.000000  47174.000000
#
#         three_half_star     four_star  four_half_star      five_star
# count       2766.000000   2766.000000     2766.000000    2766.000000
# unique              NaN           NaN             NaN            NaN
# top                 NaN           NaN             NaN            NaN
# freq                NaN           NaN             NaN            NaN
# mean        1107.255604   1646.425524      592.789588     975.857918
# std         3994.343094   7564.221355     3348.985446    6315.025111
# min            0.000000      0.000000        0.000000       0.000000
# 25%           11.000000      9.000000        2.000000       4.000000
# 50%           40.000000     35.500000        8.000000      15.000000
# 75%          254.750000    243.000000       55.000000      90.750000
# max        45027.000000  95365.000000    71034.000000  151015.000000

# %%
animation.drop([25, 90], axis=0, inplace=True)

# %%
horror = horror[(50 <= horror.running_time) & (horror.running_time <= 240)]

# %%
horror.describe(include='all')
# Out:
#                            title         year      director  running_time  \
# count                       9878  9878.000000          9878   9878.000000
# unique                      9286          NaN          6158           NaN
# top     The Phantom of the Opera          NaN  Jesús Franco           NaN
# freq                           7          NaN            47           NaN
# mean                         NaN  1997.578052           NaN     90.489876
# std                          NaN    19.665084           NaN     14.409087
# min                          NaN  1911.000000           NaN     50.000000
# 25%                          NaN  1985.000000           NaN     83.000000
# 50%                          NaN  2005.000000           NaN     90.000000
# 75%                          NaN  2014.000000           NaN     96.000000
# max                          NaN  2020.000000           NaN    239.000000
#
#                 views          likes   avg_rating     half_star     one_star  \
# count     9878.000000    9878.000000  9878.000000   9878.000000  9878.000000
# unique            NaN            NaN          NaN           NaN          NaN
# top               NaN            NaN          NaN           NaN          NaN
# freq              NaN            NaN          NaN           NaN          NaN
# mean      4787.935412     908.379632     2.766096     58.117331   110.417696
# std      23320.841156    6502.046283     0.454086    250.413214   415.571849
# min         34.000000       0.000000     0.900000      0.000000     0.000000
# 25%        109.000000      10.000000     2.500000      2.000000     6.000000
# 50%        303.000000      33.000000     2.800000      8.000000    15.000000
# 75%       1278.000000     164.000000     3.100000     25.000000    47.000000
# max     605132.000000  261668.000000     4.300000  10250.000000  9849.000000
#
#         one_half_star      two_star  two_half_star    three_star  \
# count     9878.000000   9878.000000    9878.000000   9878.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean       103.816258    260.094554     267.169265    563.759364
# std        364.558198    936.111236     947.518758   2351.715048
# min          0.000000      0.000000       0.000000      0.000000
# 25%          6.000000     11.000000       9.000000     11.000000
# 50%         15.000000     30.000000      28.000000     36.000000
# 75%         48.000000    108.000000     115.000000    184.000000
# max       6513.000000  18043.000000   20637.000000  57592.000000
#
#         three_half_star      four_star  four_half_star      five_star
# count       9878.000000    9878.000000     9878.000000    9878.000000
# unique              NaN            NaN             NaN            NaN
# top                 NaN            NaN             NaN            NaN
# freq                NaN            NaN             NaN            NaN
# mean         465.421745     559.784774      186.869306     236.239421
# std         2334.392366    3987.211348     1771.842104    2797.768745
# min            0.000000       0.000000        0.000000       0.000000
# 25%            5.000000       3.000000        0.000000       1.000000
# 50%           18.000000      11.000000        2.000000       3.000000
# 75%          104.000000      66.750000       12.000000      15.000000
# max        55535.000000  136842.000000    65726.000000  123437.000000

# %%
scifi = scifi[(50 <= scifi.running_time) & (scifi.running_time <= 240)]

# %%
scifi.describe(include='all')
# Out:
#                title         year      director  running_time          views  \
# count           5011  5011.000000          5011   5011.000000    5011.000000
# unique          4871          NaN          3430           NaN            NaN
# top     Frankenstein          NaN  Ishirō Honda           NaN            NaN
# freq               7          NaN            24           NaN            NaN
# mean             NaN  1995.614648           NaN     94.933546   14216.274995
# std              NaN    19.625673           NaN     20.580929   57383.483951
# min              NaN  1916.000000           NaN     50.000000      35.000000
# 25%              NaN  1984.000000           NaN     85.000000     129.000000
# 50%              NaN  2000.000000           NaN     92.000000     383.000000
# 75%              NaN  2012.000000           NaN    101.000000    2326.500000
# max              NaN  2020.000000           NaN    240.000000  719791.000000
#
#                 likes   avg_rating     half_star      one_star  one_half_star  \
# count     5011.000000  5011.000000   5011.000000   5011.000000    5011.000000
# unique            NaN          NaN           NaN           NaN            NaN
# top               NaN          NaN           NaN           NaN            NaN
# freq              NaN          NaN           NaN           NaN            NaN
# mean      2830.896228     2.843983    125.773498    263.900818     238.214528
# std      15576.272124     0.513865    663.797762   1184.964283     946.713821
# min          0.000000     0.900000      0.000000      0.000000       0.000000
# 25%         13.000000     2.500000      2.000000      5.000000       5.000000
# 50%         46.000000     2.900000      8.000000     16.000000      16.000000
# 75%        298.000000     3.200000     32.000000     69.000000      70.000000
# max     260768.000000     4.400000  26627.000000  41716.000000   25062.000000
#
#             two_star  two_half_star    three_star  three_half_star  \
# count    5011.000000    5011.000000   5011.000000      5011.000000
# unique           NaN            NaN           NaN              NaN
# top              NaN            NaN           NaN              NaN
# freq             NaN            NaN           NaN              NaN
# mean      665.880263     659.455398   1520.373379      1208.969467
# std      2531.601316    2370.422914   5936.061169      5053.193002
# min         0.000000       0.000000      0.000000         0.000000
# 25%        10.000000       9.000000     13.000000         6.000000
# 50%        33.000000      29.000000     43.000000        23.000000
# 75%       170.000000     175.500000    298.000000       180.000000
# max     49076.000000   32039.000000  71584.000000     63621.000000
#
#             four_star  four_half_star      five_star
# count     5011.000000     5011.000000    5011.000000
# unique            NaN             NaN            NaN
# top               NaN             NaN            NaN
# freq              NaN             NaN            NaN
# mean      1630.885452      571.590700     848.276791
# std       8678.647603     3766.444011    6707.624285
# min          0.000000        0.000000       0.000000
# 25%          4.000000        1.000000       1.000000
# 50%         16.000000        3.000000       5.000000
# 75%        130.000000       26.000000      37.000000
# max     129365.000000    70990.000000  150869.000000

# %%
thriller = thriller[(50 <= thriller.running_time) & (thriller.running_time <= 240) & (thriller.year < 2021)]

# %%
thriller.describe(include='all')
# Out:
#           title          year          director  running_time          views  \
# count     12450  12450.000000             12450  12450.000000   12450.000000
# unique    11641           NaN              7415           NaN            NaN
# top     Missing           NaN  Alfred Hitchcock           NaN            NaN
# freq          6           NaN                37           NaN            NaN
# mean        NaN   1998.789960               NaN     99.957510    7658.063614
# std         NaN     20.109216               NaN     18.934851   32876.474930
# min         NaN   1913.000000               NaN     50.000000      33.000000
# 25%         NaN   1989.000000               NaN     89.000000     112.000000
# 50%         NaN   2006.000000               NaN     96.000000     353.000000
# 75%         NaN   2014.000000               NaN    108.000000    1897.500000
# max         NaN   2020.000000               NaN    232.000000  712015.000000
#
#                 likes    avg_rating     half_star      one_star  \
# count    12450.000000  12450.000000  12450.000000  12450.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean      1460.375341      2.930177     56.352048    121.519357
# std       9502.537210      0.447649    285.237124    501.058344
# min          0.000000      0.900000      0.000000      0.000000
# 25%         10.000000      2.700000      1.000000      3.000000
# 50%         36.000000      3.000000      5.000000     11.000000
# 75%        231.000000      3.200000     19.000000     41.000000
# max     286934.000000      4.600000  10251.000000  14296.000000
#
#         one_half_star      two_star  two_half_star    three_star  \
# count    12450.000000  12450.000000   12450.000000  12450.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean       120.379598    336.545863     364.349960    831.772610
# std        438.536947   1163.786358    1187.836322   2979.189883
# min          0.000000      0.000000       0.000000      0.000000
# 25%          4.000000     10.000000      10.000000     14.000000
# 50%         11.000000     28.000000      30.000000     50.000000
# 75%         46.000000    124.000000     145.000000    278.000000
# max       9557.000000  27060.000000   25535.000000  58742.000000
#
#         three_half_star      four_star  four_half_star      five_star
# count      12450.000000   12450.000000    12450.000000   12450.000000
# unique              NaN            NaN             NaN            NaN
# top                 NaN            NaN             NaN            NaN
# freq                NaN            NaN             NaN            NaN
# mean         740.644016     972.594779      367.080884     440.363614
# std         2987.179619    5556.167893     2859.217368    4794.119138
# min            0.000000       0.000000        0.000000       0.000000
# 25%            7.000000       4.000000        0.000000       1.000000
# 50%           29.000000      18.000000        3.000000       4.000000
# 75%          191.000000     136.000000       25.000000      25.000000
# max        53357.000000  136870.000000    90025.000000  243931.000000

# %% [markdown]
# ## Exploratary Data Anlaysis

# %%
animation['year']
# Out:
# 0       2018.0
# 1       2016.0
# 2       2012.0
# 3       2010.0
# 4       2010.0
#          ...
# 8118    2018.0
# 8119    2001.0
# 8120    2015.0
# 8121    2017.0
# 8122    1994.0
# Name: year, Length: 2764, dtype: float64

# %%
animation['year'] = animation['year'].astype(int)

# %%
horror['year'] = horror['year'].astype(int)

# %%
scifi['year'] = scifi['year'].astype(int)

# %%
thriller['year'] = thriller['year'].astype(int)

# %%
animation['year']
# Out:
# 0       2018
# 1       2016
# 2       2012
# 3       2010
# 4       2010
#         ...
# 8118    2018
# 8119    2001
# 8120    2015
# 8121    2017
# 8122    1994
# Name: year, Length: 2764, dtype: int32

# %%
animation_rating_mean = round(animation['avg_rating'].mean(), 2)
animation_rating_std = round(animation['avg_rating'].std(), 2)
animation_rating_skp = round(animation['avg_rating'].skew(), 2)

# %%
horror_rating_mean = round(horror['avg_rating'].mean(), 2)
horror_rating_std = round(horror['avg_rating'].std(), 2)
horror_rating_skp = round(horror['avg_rating'].skew(), 2)

# %%
scifi_rating_mean = round(scifi['avg_rating'].mean(), 2)
scifi_rating_std = round(scifi['avg_rating'].std(), 2)
scifi_rating_skp = round(scifi['avg_rating'].skew(), 2)

# %%
thriller_rating_mean = round(thriller['avg_rating'].mean(), 2)
thriller_rating_std = round(thriller['avg_rating'].std(), 2)
thriller_rating_skp = round(thriller['avg_rating'].skew(), 2)

# %%
animation_n_movies = len(animation)
horror_n_movies = len(horror)
scifi_n_movies = len(scifi)
thriller_n_movies = len(thriller)

# %% [markdown]
# ## Average Rating Distribution

# %%
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10), squeeze=True)
fig.suptitle('Average Rating Distributions per Genre', fontsize=25)

sns.distplot(animation.avg_rating, ax=axes[0,0], norm_hist=True,
             color='y', axlabel=False, label=f'Total of {animation_n_movies} Movies')
axes[0,0].set_title(f'Animation (μ = {animation_rating_mean}, σ = {animation_rating_std}, Skp = {animation_rating_skp})',
                    fontsize=20)
axes[0,0].legend(loc='upper left')

sns.distplot(horror.avg_rating, ax=axes[0,1], norm_hist=True,
             color='r', axlabel=False, label=f'Total of {horror_n_movies} Movies')
axes[0,1].set_title(f'Horror (μ = {horror_rating_mean}, σ = {horror_rating_std}, Skp = {horror_rating_skp})',
                    fontsize=20)
axes[0,1].legend(loc='upper left')

sns.distplot(scifi.avg_rating, ax=axes[1,0], norm_hist=True,
             color='g', axlabel=False, label=f'Total of {scifi_n_movies} Movies')
axes[1,0].set_title(f'SciFi (μ = {scifi_rating_mean}, σ = {scifi_rating_std}, Skp = {scifi_rating_skp})',
                    fontsize=20)
axes[1,0].legend(loc='upper left')

sns.distplot(thriller.avg_rating, ax=axes[1,1], norm_hist=True,
             color='k', axlabel=False, label=f'Total of {thriller_n_movies} Movies')
axes[1,1].set_title(f'Thriller (μ = {thriller_rating_mean}, σ = {thriller_rating_std}, Skp = {thriller_rating_skp})', fontsize=20)
axes[1,1].legend(loc='upper left')

plt.show()

# %% [markdown]
# ## Outliers

# %%
sns.boxplot(y='avg_rating',data=animation,color='r')
# Out:
# <AxesSubplot:ylabel='avg_rating'>

# %%
sns.boxplot(y='avg_rating',data=horror)
# Out:
# <AxesSubplot:ylabel='avg_rating'>

# %%
sns.boxplot(y='avg_rating',data=scifi,color='g')
# Out:
# <AxesSubplot:ylabel='avg_rating'>

# %%
sns.boxplot(y='avg_rating',data=thriller,color='m')
# Out:
# <AxesSubplot:ylabel='avg_rating'>

# %%
def outlier_fences(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    
    iqr = q3 - q1
    
    lower = q1 - 1.5*iqr
    upper = q3 + 1.5*iqr
    
    return [lower, upper]

# %%
anim_fences = outlier_fences(animation, 'avg_rating')

# %%
worst_rated_anim = animation[animation.avg_rating < anim_fences[0]]
worst_rated_anim.sort_values('avg_rating').head()
# Out:
#                                title  year           director  running_time  \
# 7723                      Foodfight!  2012  Lawrence Kasanoff            87
# 7169  Titanic: The Legend Goes On...  2001       Camillo Teti            90
# 7613               Norm of the North  2016        Trevor Wall            86
# 6927        The Little Panda Fighter  2008   Michelle Gabriel            51
# 7465                The Amazing Bulk  2012   Lewis Schoenbrun            76
#
#       views  likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 7723   6828    437         0.9       3533       608            101        65
# 7169   1570     69         1.0        636       176             32        23
# 7613   4304    108         1.0       1809       612            175       135
# 6927   1045     74         1.1        546       105             14        17
# 7465   2536    297         1.2       1186       276             58        43
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 7723             38          26               19         25              11
# 7169             10           8                8          3               4
# 7613             59          67               18         21               5
# 6927              4           5                1          2               1
# 7465             14          24               17         26              12
#
#       five_star
# 7723        184
# 7169         32
# 7613         66
# 6927         36
# 7465        158

# %%
best_rated_anim = animation[animation.avg_rating > anim_fences[1]]
best_rated_anim.sort_values('avg_rating').sort_values('avg_rating', ascending=False)
# Out:
#                                                title  year  \
# 8119                                   Spirited Away  2001
# 0                  Spider-Man: Into the Spider-Verse  2018
# 5                                  Princess Mononoke  1997
# 8028  Neon Genesis Evangelion: The End of Evangelion  1997
# 8039                       It's Such a Beautiful Day  2012
# 8091                                    Perfect Blue  1997
# 8095                          Grave of the Fireflies  1988
# 11                                        Your Name.  2016
# 18                              Howl's Moving Castle  2004
# 7292                             Rilakkuma and Kaoru  2019
# 8098                                  The Iron Giant  1999
# 8100                                           Akira  1988
# 8103                              My Neighbor Totoro  1988
# 8115                                       Toy Story  1995
# 8121                                            Coco  2017
# 8122                                   The Lion King  1994
#
#                                          director  running_time   views  \
# 8119                               Hayao Miyazaki           125  437759
# 0     Rodney Rothman,Peter Ramsey,Bob Persichetti           117  471600
# 5                                  Hayao Miyazaki           134  214237
# 8028                Hideaki Anno,Kazuya Tsurumaki            87   54217
# 8039                               Don Hertzfeldt            62   35875
# 8091                                  Satoshi Kon            81   91101
# 8095                                Isao Takahata            89  126525
# 11                                 Makoto Shinkai           106  175635
# 18                                 Hayao Miyazaki           119  207310
# 7292                           Masahito Kobayashi           151    1245
# 8098                                    Brad Bird            86  201697
# 8100                              Katsuhiro Otomo           124  146667
# 8103                               Hayao Miyazaki            86  256960
# 8115                                John Lasseter            81  558071
# 8121                    Lee Unkrich,Adrian Molina           105  399757
# 8122                     Roger Allers,Rob Minkoff            89  508841
#
#        likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 8119  178080         4.5        257       512            291      1687
# 0     232066         4.4        275       585            329      1929
# 5      76679         4.3         84       187            145       900
# 8028   19992         4.3        127       157            156       412
# 8039   13329         4.3         56       114             78       306
# 8091   35405         4.3         47       114             92       434
# 8095   40588         4.3        112       183            168       704
# 11     68673         4.2        257       387            425      1701
# 18     70875         4.2         69       200            232      1125
# 7292     519         4.2          0         2              3         5
# 8098   58407         4.2         65       200            139      1045
# 8100   50415         4.2         95       290            277      1184
# 8103   88144         4.2        112       269            279      1342
# 8115  142682         4.2        215       641            354      2661
# 8121  148759         4.2        249       583            418      2824
# 8122  133002         4.2        274       637            468      2728
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 8119           1760       10355            14469      56612           43915
# 0              2184       13931            22173      84347           71034
# 5              1216        6549            10927      32934           25078
# 8028            546        1843             2449       6910            5789
# 8039            339        1343             1940       5275            4326
# 8091            681        3012             5844      17688           13882
# 8095            966        3760             6235      18915           15316
# 11             2305        8738            13399      31838           22584
# 18             1828        8763            15046      34983           18480
# 7292              9          41               84        233             110
# 8098           1289        8148            11265      30570           16407
# 8100           1678        6554            10028      24989           16733
# 8103           2001       11052            16923      45122           23310
# 8115           2733       21624            23913      79086           35697
# 8121           3733       21015            27725      78045           41393
# 8122           2941       18910            20447      63609           31847
#
#       five_star
# 8119     121555
# 0        151015
# 5         43308
# 8028      13323
# 8039       8397
# 8091      17324
# 8095      27127
# 11        37559
# 18        32457
# 7292        241
# 8098      26388
# 8100      25262
# 8103      43035
# 8115      81041
# 8121      77480
# 8122      82555

# %%
horror_fences = outlier_fences(horror, 'avg_rating')

# %%
worst_rated_horror = horror[horror.avg_rating < horror_fences[0]]
worst_rated_horror.sort_values('avg_rating').sort_values('avg_rating').head()
# Out:
#                                  title  year            director  \
# 761           Potato Salad: Don't Ask!  2015  Michael David Pate
# 703                     Jurassic Shark  2012         Brett Kelly
# 9445  Fred 2: Night of the Living Fred  2011    John Fortenberry
# 8412                            Romina  2018         Diego Cohen
# 8518              American Poltergeist  2015      Mike Rutkowski
#
#       running_time  views  likes  avg_rating  half_star  one_star  \
# 761             81   1296     18         0.9        770       148
# 703             75   1032     39         1.0        490       141
# 9445            84   4260    150         1.0       1474       647
# 8412            74   1006     24         1.1        413       194
# 8518            77   1089     33         1.1        483       173
#
#       one_half_star  two_star  two_half_star  three_star  three_half_star  \
# 761              41        24             11           6                3
# 703              32        22              6          10                2
# 9445            133       109             60          67               22
# 8412             74        48             23          16                3
# 8518             45        50              9          18                1
#
#       four_star  four_half_star  five_star
# 761           4               0         12
# 703           3               2          9
# 9445         11               1         46
# 8412          6               0          3
# 8518          5               0         10

# %%
best_rated_horror = horror[horror.avg_rating > horror_fences[1]]
best_rated_horror.sort_values('avg_rating').sort_values('avg_rating', ascending=False)
# Out:
#                                      title  year  \
# 11046             The Silence of the Lambs  1991
# 11041                                Alien  1979
# 11039                               Psycho  1960
# 7                                The Thing  1982
# 11049                          The Shining  1980
# 4                          Rosemary's Baby  1968
# 8827            In Just the Wink of an Eye  1981
# 11044                                 Jaws  1975
# 11051                       The Lighthouse  2019
# 9797   National Theatre Live: Frankenstein  2011
# 0                                  Get Out  2017
# 207                                 Demons  1971
# 8926                      Manichitrathazhu  1993
# 10672                                Faust  1926
# 10535                         The Cremator  1969
# 10821                              Kwaidan  1964
# 10892     What Ever Happened to Baby Jane?  1962
# 10911                           Diabolique  1955
# 10994                           Possession  1981
# 14               What We Do in the Shadows  2014
#
#                             director  running_time   views   likes  \
# 11046                 Jonathan Demme           119  482939  161110
# 11041                   Ridley Scott           117  379504  130782
# 11039               Alfred Hitchcock           109  323090  101065
# 7                     John Carpenter           109  215480   78005
# 11049                Stanley Kubrick           144  535777  196151
# 4                     Roman Polanski           137  158689   46272
# 8827                    Mike de Leon            98     276     105
# 11044               Steven Spielberg           124  354355   88582
# 11051                  Robert Eggers           109  237969   93329
# 9797     Danny Boyle,Tim Van Someren           239    2950     838
# 0                       Jordan Peele           104  605132  261668
# 207                 Toshio Matsumoto           134    1860     593
# 8926                           Fazil           169     650     270
# 10672                    F.W. Murnau           116   10301    2438
# 10535                     Juraj Herz           100    5941    1764
# 10821               Masaki Kobayashi           183   13312    4086
# 10892                 Robert Aldrich           135   33151    9247
# 10911          Henri-Georges Clouzot           117   29060    8001
# 10994               Andrzej Żuławski           123   42312   14804
# 14     Taika Waititi,Jemaine Clement            86  210944   80476
#
#        avg_rating  half_star  one_star  one_half_star  two_star  \
# 11046         4.3        148       365            259      1727
# 11041         4.3        146       442            299      1973
# 11039         4.3         85       229            167      1161
# 7             4.3        112       324            247      1339
# 11049         4.3        463      1016            610      3798
# 4             4.2        156       372            253      1326
# 8827          4.2          0         0              0         1
# 11044         4.1        294       990            554      3792
# 11051         4.1        564      1182            849      3895
# 9797          4.1          4         8              7        25
# 0             4.1        647      1560           1001      5727
# 207           4.1          0         2              1        15
# 8926          4.1          0         3              2         8
# 10672         4.1          5        17             20        70
# 10535         4.1          5        12             15        59
# 10821         4.1          9        21             24        98
# 10892         4.1         10        52             46       221
# 10911         4.1          8        21             37       148
# 10994         4.1        140       207            193       616
# 14            4.1        177       378            294      1549
#
#        two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 11046           1904       14691            20634      80047           51372
# 11041           1963       13696            17644      60265           38066
# 11039           1335       10300            13792      50703           33030
# 7               1539        8292            12174      35860           24541
# 11049           3328       20073            22634      82486           52363
# 4               1412        6933             9562      27455           18616
# 8827               0           9               12         39              43
# 11044           3510       20468            21237      51850           23165
# 11051           4514       14861            21755      54557           38452
# 9797              30         126              244        661             361
# 0               5821       34069            45053     136842           65726
# 207               30          62              153        380             288
# 8926               6          27               48        100              78
# 10672            143         522              839       1915            1172
# 10535             68         292              521       1262             867
# 10821            134         639             1108       2762            1816
# 10892            329        1620             2756       6569            3522
# 10911            275        1305             2494       6629            3892
# 10994            710        2055             2995       7460            5318
# 14              2260       11534            21547      49711           23046
#
#        five_star
# 11046      92363
# 11041      81281
# 11039      63548
# 7          48856
# 11049     123437
# 4          24435
# 8827          58
# 11044      49721
# 11051      50018
# 9797         368
# 0         110264
# 207          262
# 8926         118
# 10672       1148
# 10535        826
# 10821       1785
# 10892       4029
# 10911       3064
# 10994       7781
# 14         28627

# %%
scifi_fences = outlier_fences(scifi, 'avg_rating')

# %%
worst_rated_scifi = scifi[scifi.avg_rating < scifi_fences[0]]
worst_rated_scifi.sort_values('avg_rating').sort_values('avg_rating').head()
# Out:
#                              title  year         director  running_time  \
# 5380          Dragonball Evolution  2009       James Wong            85
# 323                   Atlantic Rim  2013       Jared Cohn            85
# 4387                Jurassic Shark  2012      Brett Kelly            75
# 132              Battlefield Earth  2000  Roger Christian           118
# 4783  Birdemic 2: The Resurrection  2013     James Nguyen            82
#
#       views  likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 5380  25282    350         0.9       9251      3144            831       722
# 323    2060     66         1.0        733       384             98        64
# 4387   1032     39         1.0        490       141             32        22
# 132   16915    511         1.1       4627      2539            712       602
# 4783   2415    162         1.1       1028       252             56        53
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 5380            241         211               43         44               6
# 323              28          29               10          8               3
# 4387              6          10                2          3               2
# 132             238         261              103         78              24
# 4783             35          33               17         30              12
#
#       five_star
# 5380         72
# 323           7
# 4387          9
# 132          96
# 4783         49

# %%
best_rated_scifi = scifi[scifi.avg_rating > scifi_fences[1]]
best_rated_scifi.sort_values('avg_rating').sort_values('avg_rating', ascending=False)
# Out:
#                                                title  year  \
# 0                  Spider-Man: Into the Spider-Verse  2018
# 9                            The Empire Strikes Back  1980
# 5760                                         Stalker  1979
# 1                                              Alien  1979
# 12                             2001: A Space Odyssey  1968
# 5652  Neon Genesis Evangelion: The End of Evangelion  1997
# 5787                                       The Thing  1982
# 5811                                       Star Wars  1977
#
#                                          director  running_time   views  \
# 0     Rodney Rothman,Peter Ramsey,Bob Persichetti           117  471056
# 9                                  Irvin Kershner           124  506762
# 5760                             Andrey Tarkovsky           162   80202
# 1                                    Ridley Scott           117  379337
# 12                                Stanley Kubrick           149  339349
# 5652                Hideaki Anno,Kazuya Tsurumaki            87   54131
# 5787                               John Carpenter           109  215385
# 5811                                 George Lucas           121  548822
#
#        likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 0     231832         4.4        275       585            330      1923
# 9     180467         4.4        228       473            268      1861
# 5760   28967         4.4        121       220            211       596
# 1     130733         4.3        145       442            299      1974
# 12    117398         4.3        767      1662            863      3863
# 5652   19965         4.3        127       157            156       412
# 5787   77971         4.3        112       324            247      1337
# 5811  189813         4.3        317       723            411      2841
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 0              2178       13916            22153      84260           70990
# 9              2023       15036            16978      62922           44127
# 5760            691        2314             3277       9860            9856
# 1              1961       13690            17632      60239           38044
# 12             2860       12669            12115      38334           28574
# 5652            543        1840             2445       6900            5774
# 5787           1538        8285            12168      35842           24522
# 5811           3223       22991            26838      87856           46209
#
#       five_star
# 0        150869
# 9        127552
# 5760      23385
# 1         81236
# 12        94504
# 5652      13306
# 5787      48840
# 5811     101821

# %%
thriller_fences = outlier_fences(thriller, 'avg_rating')

# %%
worst_rated_thriller = thriller[thriller.avg_rating < thriller_fences[0]]
worst_rated_thriller.sort_values('avg_rating').sort_values('avg_rating').head()
# Out:
#                                     title  year         director  \
# 11964                Dragonball Evolution  2009       James Wong
# 11268                   Alone in the Dark  2005         Uwe Boll
# 9167   The Murder of Nicole Brown Simpson  2019  Daniel Farrands
# 9509                               Romina  2018      Diego Cohen
# 10105                           Titanic 2  2010   Shane van Dyke
#
#        running_time  views  likes  avg_rating  half_star  one_star  \
# 11964            85  25297    349         0.9       9259      3144
# 11268            96   7568    139         1.1       1906      1171
# 9167             86    465     11         1.1        307        55
# 9509             74   1006     24         1.1        413       194
# 10105            90   1989     63         1.1        697       295
#
#        one_half_star  two_star  two_half_star  three_star  three_half_star  \
# 11964            831       722            241         211               43
# 11268            397       350            138         132               32
# 9167              14        11             10           7                2
# 9509              74        48             23          16                3
# 10105             89        67             20          22                9
#
#        four_star  four_half_star  five_star
# 11964         44               6         71
# 11268         29               1         17
# 9167           2               0          3
# 9509           6               0          3
# 10105          7               1         26

# %%
best_rated_thriller = thriller[thriller.avg_rating > thriller_fences[1]]
best_rated_thriller.sort_values('avg_rating').sort_values('avg_rating', ascending=False)
# Out:
#                              title  year                  director  \
# 0                         Parasite  2019              Bong Joon-ho
# 12590                 High and Low  1963            Akira Kurosawa
# 12474           Woman in the Dunes  1964       Hiroshi Teshigahara
# 12833                 Pulp Fiction  1994         Quentin Tarantino
# 12835              The Dark Knight  2008         Christopher Nolan
# ...                            ...   ...                       ...
# 9307              Time for Revenge  1981         Adolfo Aristarain
# 12043  The Testament of Dr. Mabuse  1933                Fritz Lang
# 12815                    Good Time  2017  Josh Safdie,Benny Safdie
# 12614                        Caché  2005            Michael Haneke
# 12453                  Hard Boiled  1992                  John Woo
#
#        running_time   views   likes  avg_rating  half_star  one_star  \
# 0               133  539266  283450         4.6        308       427
# 12590           142   26773    9744         4.4          3        15
# 12474           123   17151    5783         4.4         20        25
# 12833           154  693834  286934         4.4        642      1592
# 12835           152  712015  286444         4.4        418       961
# ...             ...     ...     ...         ...        ...       ...
# 9307            112     609     169         4.0          0         1
# 12043           122    7123    1610         4.0          3        10
# 12815           102  162732   57063         4.0        150       325
# 12614           117   46528   11122         4.0         81       163
# 12453           126   28388    7899         4.0         15        44
#
#        one_half_star  two_star  two_half_star  three_star  three_half_star  \
# 0                289      1266           1640        8667            14524
# 12590              8        53             93         506             1084
# 12474             16        77             96         431              770
# 12833            738      4727           3552       24158            24063
# 12835            539      3362           3224       20605            22880
# ...              ...       ...            ...         ...              ...
# 9307               0         5             10          32               61
# 12043              9        54             86         389              648
# 12815            360      1553           2559       10397            21016
# 12614            133       575            764        2654             4394
# 12453             48       220            393        1634             2625
#
#        four_star  four_half_star  five_star
# 0          69003           90025     243931
# 12590       4071            4835       6769
# 12474       2656            2745       3724
# 12833      97896           65407     181714
# 12835      96118           71165     187892
# ...          ...             ...        ...
# 9307         115              66         87
# 12043       1465             742        636
# 12815      47019           24533      16942
# 12614       8903            5164       4864
# 12453       5648            2935       3186
#
# [141 rows x 17 columns]

# %% [markdown]
# ## Average Rating By Year

# %%
animation_by_year = animation.groupby('year').mean()[['avg_rating', 'likes', 'views']]
horror_by_year = horror.groupby('year').mean()[['avg_rating', 'likes', 'views']]
scifi_by_year = scifi.groupby('year').mean()[['avg_rating', 'likes', 'views']]
thriller_by_year = thriller.groupby('year').mean()[['avg_rating', 'likes', 'views']]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10), squeeze=True)
fig.suptitle('Average Rating per Year', fontsize=25)


sns.scatterplot(data = animation_by_year.avg_rating, ax=axes[0,0], color='m',
               alpha=0.75)
axes[0,0].set_title('Animation', fontsize=20)
axes[0,0].set_ylabel('Average Rating')
axes[0,0].set_ylim((2.4,4))

sns.scatterplot(data = horror_by_year.avg_rating, ax=axes[0,1], color='r',
               alpha=0.75)
axes[0,1].set_title('Horror', fontsize=20)
axes[0,1].set_ylim((2.4,4))

sns.scatterplot(data = scifi_by_year.avg_rating, ax=axes[1,0], color='g',
               alpha=0.75)
axes[1,0].set_title('SciFi', fontsize=20)
axes[1,0].set_ylabel('Average Rating')
axes[1,0].set_xlabel('Year')
axes[1,0].set_ylim((2.4,4))

sns.scatterplot(data = thriller_by_year.avg_rating, ax=axes[1,1], color='k',
               alpha=0.75)
axes[1,1].set_title('Thriller', fontsize=20)
axes[1,1].set_xlabel('Year')
axes[1,1].set_ylim((2.4,4))

plt.show()

# %% [markdown]
# ## Animation

# %%
top_animation = animation.nlargest(15, 'avg_rating')
top_animation
# Out:
#                                                title  year  \
# 8119                                   Spirited Away  2001
# 0                  Spider-Man: Into the Spider-Verse  2018
# 5                                  Princess Mononoke  1997
# 8028  Neon Genesis Evangelion: The End of Evangelion  1997
# 8039                       It's Such a Beautiful Day  2012
# 8091                                    Perfect Blue  1997
# 8095                          Grave of the Fireflies  1988
# 11                                        Your Name.  2016
# 18                              Howl's Moving Castle  2004
# 7292                             Rilakkuma and Kaoru  2019
# 8098                                  The Iron Giant  1999
# 8100                                           Akira  1988
# 8103                              My Neighbor Totoro  1988
# 8115                                       Toy Story  1995
# 8121                                            Coco  2017
#
#                                          director  running_time   views  \
# 8119                               Hayao Miyazaki           125  437759
# 0     Rodney Rothman,Peter Ramsey,Bob Persichetti           117  471600
# 5                                  Hayao Miyazaki           134  214237
# 8028                Hideaki Anno,Kazuya Tsurumaki            87   54217
# 8039                               Don Hertzfeldt            62   35875
# 8091                                  Satoshi Kon            81   91101
# 8095                                Isao Takahata            89  126525
# 11                                 Makoto Shinkai           106  175635
# 18                                 Hayao Miyazaki           119  207310
# 7292                           Masahito Kobayashi           151    1245
# 8098                                    Brad Bird            86  201697
# 8100                              Katsuhiro Otomo           124  146667
# 8103                               Hayao Miyazaki            86  256960
# 8115                                John Lasseter            81  558071
# 8121                    Lee Unkrich,Adrian Molina           105  399757
#
#        likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 8119  178080         4.5        257       512            291      1687
# 0     232066         4.4        275       585            329      1929
# 5      76679         4.3         84       187            145       900
# 8028   19992         4.3        127       157            156       412
# 8039   13329         4.3         56       114             78       306
# 8091   35405         4.3         47       114             92       434
# 8095   40588         4.3        112       183            168       704
# 11     68673         4.2        257       387            425      1701
# 18     70875         4.2         69       200            232      1125
# 7292     519         4.2          0         2              3         5
# 8098   58407         4.2         65       200            139      1045
# 8100   50415         4.2         95       290            277      1184
# 8103   88144         4.2        112       269            279      1342
# 8115  142682         4.2        215       641            354      2661
# 8121  148759         4.2        249       583            418      2824
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 8119           1760       10355            14469      56612           43915
# 0              2184       13931            22173      84347           71034
# 5              1216        6549            10927      32934           25078
# 8028            546        1843             2449       6910            5789
# 8039            339        1343             1940       5275            4326
# 8091            681        3012             5844      17688           13882
# 8095            966        3760             6235      18915           15316
# 11             2305        8738            13399      31838           22584
# 18             1828        8763            15046      34983           18480
# 7292              9          41               84        233             110
# 8098           1289        8148            11265      30570           16407
# 8100           1678        6554            10028      24989           16733
# 8103           2001       11052            16923      45122           23310
# 8115           2733       21624            23913      79086           35697
# 8121           3733       21015            27725      78045           41393
#
#       five_star
# 8119     121555
# 0        151015
# 5         43308
# 8028      13323
# 8039       8397
# 8091      17324
# 8095      27127
# 11        37559
# 18        32457
# 7292        241
# 8098      26388
# 8100      25262
# 8103      43035
# 8115      81041
# 8121      77480

# %% [markdown]
# ## Miyazaki Analysis

# %%
miyazaki_films = animation[animation['director'] == 'Hayao Miyazaki'].sort_values('avg_rating', ascending=False)

# %%
miyazaki_films['avg_rating'].mean()
# Out:
# 4.063636363636363

# %%
animation.avg_rating.mean()
# Out:
# 3.1286541244573156

# %%
animation['avg_rating'].std()
# Out:
# 0.47830628967991456

# %% [markdown]
# ## Horror

# %%
horror.nlargest(15, 'avg_rating')
# Out:
#                                      title  year  \
# 7                                The Thing  1982
# 11039                               Psycho  1960
# 11041                                Alien  1979
# 11046             The Silence of the Lambs  1991
# 11049                          The Shining  1980
# 4                          Rosemary's Baby  1968
# 8827            In Just the Wink of an Eye  1981
# 0                                  Get Out  2017
# 14               What We Do in the Shadows  2014
# 207                                 Demons  1971
# 8926                      Manichitrathazhu  1993
# 9797   National Theatre Live: Frankenstein  2011
# 10535                         The Cremator  1969
# 10672                                Faust  1926
# 10821                              Kwaidan  1964
#
#                             director  running_time   views   likes  \
# 7                     John Carpenter           109  215480   78005
# 11039               Alfred Hitchcock           109  323090  101065
# 11041                   Ridley Scott           117  379504  130782
# 11046                 Jonathan Demme           119  482939  161110
# 11049                Stanley Kubrick           144  535777  196151
# 4                     Roman Polanski           137  158689   46272
# 8827                    Mike de Leon            98     276     105
# 0                       Jordan Peele           104  605132  261668
# 14     Taika Waititi,Jemaine Clement            86  210944   80476
# 207                 Toshio Matsumoto           134    1860     593
# 8926                           Fazil           169     650     270
# 9797     Danny Boyle,Tim Van Someren           239    2950     838
# 10535                     Juraj Herz           100    5941    1764
# 10672                    F.W. Murnau           116   10301    2438
# 10821               Masaki Kobayashi           183   13312    4086
#
#        avg_rating  half_star  one_star  one_half_star  two_star  \
# 7             4.3        112       324            247      1339
# 11039         4.3         85       229            167      1161
# 11041         4.3        146       442            299      1973
# 11046         4.3        148       365            259      1727
# 11049         4.3        463      1016            610      3798
# 4             4.2        156       372            253      1326
# 8827          4.2          0         0              0         1
# 0             4.1        647      1560           1001      5727
# 14            4.1        177       378            294      1549
# 207           4.1          0         2              1        15
# 8926          4.1          0         3              2         8
# 9797          4.1          4         8              7        25
# 10535         4.1          5        12             15        59
# 10672         4.1          5        17             20        70
# 10821         4.1          9        21             24        98
#
#        two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 7               1539        8292            12174      35860           24541
# 11039           1335       10300            13792      50703           33030
# 11041           1963       13696            17644      60265           38066
# 11046           1904       14691            20634      80047           51372
# 11049           3328       20073            22634      82486           52363
# 4               1412        6933             9562      27455           18616
# 8827               0           9               12         39              43
# 0               5821       34069            45053     136842           65726
# 14              2260       11534            21547      49711           23046
# 207               30          62              153        380             288
# 8926               6          27               48        100              78
# 9797              30         126              244        661             361
# 10535             68         292              521       1262             867
# 10672            143         522              839       1915            1172
# 10821            134         639             1108       2762            1816
#
#        five_star
# 7          48856
# 11039      63548
# 11041      81281
# 11046      92363
# 11049     123437
# 4          24435
# 8827          58
# 0         110264
# 14         28627
# 207          262
# 8926         118
# 9797         368
# 10535        826
# 10672       1148
# 10821       1785

# %%
horror[horror['title'] == 'The Witch']
# Out:
#            title  year             director  running_time   views  likes  \
# 1184   The Witch  1952  Roland af Hällström            74     151     37
# 4598   The Witch  1954         Chano Urueta            90      52      7
# 7627   The Witch  1966      Damiano Damiani           109     195     32
# 11042  The Witch  2015        Robert Eggers            92  265695  83771
#
#        avg_rating  half_star  one_star  one_half_star  two_star  \
# 1184          3.3          0         1              4         4
# 4598          3.4          0         0              1         2
# 7627          3.4          0         1              2         9
# 11042         3.8       1042      2425           1446      6307
#
#        two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 1184               9          30               23         33               1
# 4598               2           9               13          3               0
# 7627              16          29               32         26               7
# 11042           5999       20950            27476      57322           26689
#
#        five_star
# 1184           1
# 4598           2
# 7627           7
# 11042      30475

# %%
horror[horror['title'] == 'The Thing']
# Out:
#         title  year                     director  running_time   views  likes  \
# 7   The Thing  1982               John Carpenter           109  215480  78005
# 76  The Thing  2011  Matthijs van Heijningen Jr.           103   40852   3854
#
#     avg_rating  half_star  one_star  one_half_star  two_star  two_half_star  \
# 7          4.3        112       324            247      1339           1539
# 76         2.7        447      1080           1508      4158           4275
#
#     three_star  three_half_star  four_star  four_half_star  five_star
# 7         8292            12174      35860           24541      48856
# 76        6187             3105       1644             239        354

# %%
horror.avg_rating.mean()
# Out:
# 2.7660963757845733

# %%
horror.avg_rating.std()
# Out:
# 0.45408562051596413

# %% [markdown]
# ## Sci-Fi

# %%
scifi.nlargest(15, 'avg_rating')
# Out:
#                                                title  year  \
# 0                  Spider-Man: Into the Spider-Verse  2018
# 9                            The Empire Strikes Back  1980
# 5760                                         Stalker  1979
# 1                                              Alien  1979
# 12                             2001: A Space Odyssey  1968
# 5652  Neon Genesis Evangelion: The End of Evangelion  1997
# 5787                                       The Thing  1982
# 5811                                       Star Wars  1977
# 16                        Terminator 2: Judgment Day  1991
# 30                                           Solaris  1972
# 48                        Black Mirror: San Junipero  2016
# 3504               Doctor Who: Genesis of the Daleks  1975
# 4147                                      Dandy Dust  1998
# 4601                                         Firefly  2005
# 5724                                      Metropolis  1927
#
#                                          director  running_time   views  \
# 0     Rodney Rothman,Peter Ramsey,Bob Persichetti           117  471056
# 9                                  Irvin Kershner           124  506762
# 5760                             Andrey Tarkovsky           162   80202
# 1                                    Ridley Scott           117  379337
# 12                                Stanley Kubrick           149  339349
# 5652                Hideaki Anno,Kazuya Tsurumaki            87   54131
# 5787                               John Carpenter           109  215385
# 5811                                 George Lucas           121  548822
# 16                                  James Cameron           156  268780
# 30                               Andrey Tarkovsky           167   62498
# 48                                    Owen Harris            60   97064
# 3504                                David Maloney           143     479
# 4147                              A. Hans Scheirl            94     291
# 4601                                  Peter Marcy           104    1867
# 5724                                   Fritz Lang           153   92252
#
#        likes  avg_rating  half_star  one_star  one_half_star  two_star  \
# 0     231832         4.4        275       585            330      1923
# 9     180467         4.4        228       473            268      1861
# 5760   28967         4.4        121       220            211       596
# 1     130733         4.3        145       442            299      1974
# 12    117398         4.3        767      1662            863      3863
# 5652   19965         4.3        127       157            156       412
# 5787   77971         4.3        112       324            247      1337
# 5811  189813         4.3        317       723            411      2841
# 16     77191         4.2        137       353            254      1812
# 30     18165         4.2         57       161            151       608
# 48     27574         4.2        116       244            227       856
# 3504     153         4.2          0         0              0         1
# 4147      47         4.2          2         3              2         2
# 4601      43         4.2         10         4              7        17
# 5724   23800         4.2         85       181            157       669
#
#       two_half_star  three_star  three_half_star  four_star  four_half_star  \
# 0              2178       13916            22153      84260           70990
# 9              2023       15036            16978      62922           44127
# 5760            691        2314             3277       9860            9856
# 1              1961       13690            17632      60239           38044
# 12             2860       12669            12115      38334           28574
# 5652            543        1840             2445       6900            5774
# 5787           1538        8285            12168      35842           24522
# 5811           3223       22991            26838      87856           46209
# 16             1946       11120            13982      40298           26341
# 30              727        2349             3615       9830            8301
# 48             1063        4071             5361      13961            8820
# 3504              4          16               25         63              41
# 4147              5          16               16         14              12
# 4601             24          71              136        274             343
# 5724            775        3682             4552      13125            8196
#
#       five_star
# 0        150869
# 9        127552
# 5760      23385
# 1         81236
# 12        94504
# 5652      13306
# 5787      48840
# 5811     101821
# 16        42377
# 30        10518
# 48        15685
# 3504        106
# 4147        131
# 4601        321
# 5724      14761

# %%
scifi[scifi['title'] == 'Spider-Man: Into the Spider-Verse']
# Out:
#                                title  year  \
# 0  Spider-Man: Into the Spider-Verse  2018
#
#                                       director  running_time   views   likes  \
# 0  Rodney Rothman,Peter Ramsey,Bob Persichetti           117  471056  231832
#
#    avg_rating  half_star  one_star  one_half_star  two_star  two_half_star  \
# 0         4.4        275       585            330      1923           2178
#
#    three_star  three_half_star  four_star  four_half_star  five_star
# 0       13916            22153      84260           70990     150869

# %%
scifi.avg_rating.mean()
# Out:
# 2.8439832368788704

# %%
scifi.avg_rating.std()
# Out:
# 0.5138648700864449

# %% [markdown]
# ## Thriller

# %%
thriller.nlargest(15, 'avg_rating')
# Out:
#                         title  year              director  running_time  \
# 0                    Parasite  2019          Bong Joon-ho           133
# 12474      Woman in the Dunes  1964   Hiroshi Teshigahara           123
# 12590            High and Low  1963        Akira Kurosawa           142
# 12833            Pulp Fiction  1994     Quentin Tarantino           154
# 12835         The Dark Knight  2008     Christopher Nolan           152
# 1                      Psycho  1960      Alfred Hitchcock           109
# 8      No Country for Old Men  2007  Joel Coen,Ethan Coen           122
# 12215                 Le Trou  1960        Jacques Becker           132
# 12429         Army of Shadows  1969  Jean-Pierre Melville           145
# 12483           A Man Escaped  1956        Robert Bresson           101
# 12719                       M  1931            Fritz Lang           117
# 12755      Memories of Murder  2003          Bong Joon-ho           131
# 12757            Perfect Blue  1997           Satoshi Kon            81
# 12793             Rear Window  1954      Alfred Hitchcock           112
# 12807                  Oldboy  2003        Park Chan-wook           120
#
#         views   likes  avg_rating  half_star  one_star  one_half_star  \
# 0      539266  283450         4.6        308       427            289
# 12474   17151    5783         4.4         20        25             16
# 12590   26773    9744         4.4          3        15              8
# 12833  693834  286934         4.4        642      1592            738
# 12835  712015  286444         4.4        418       961            539
# 1      323092  101066         4.3         85       229            167
# 8      368493  121964         4.3        281       773            429
# 12215    9685    3071         4.3          5         7              6
# 12429   16855    5099         4.3          7        21             12
# 12483   21763    6531         4.3         11        16             23
# 12719   67811   19394         4.3         23        67             57
# 12755   80165   28859         4.3         35        47             71
# 12757   91029   35364         4.3         47       114             92
# 12793  209305   68430         4.3         37       149            106
# 12807  230014   78036         4.3        292       461            328
#
#        two_star  two_half_star  three_star  three_half_star  four_star  \
# 0          1266           1640        8667            14524      69003
# 12474        77             96         431              770       2656
# 12590        53             93         506             1084       4071
# 12833      4727           3552       24158            24063      97896
# 12835      3362           3224       20605            22880      96118
# 1          1161           1335       10300            13792      50704
# 8          2600           2365       13141            17989      62060
# 12215        29             41         195              479       1805
# 12429        94            151         597             1067       3038
# 12483       100            157         671             1339       4072
# 12719       298            425        2066             3692      11056
# 12755       317            510        2487             5512      17572
# 12757       434            681        3012             5840      17671
# 12793       674            978        5937            10078      33900
# 12807      1496           1677        7224            11521      36977
#
#        four_half_star  five_star
# 0               90025     243931
# 12474            2745       3724
# 12590            4835       6769
# 12833           65407     181714
# 12835           71165     187892
# 1               33030      63548
# 8               45263      72926
# 12215            1897       1717
# 12429            2606       3247
# 12483            3179       3765
# 12719            8411      12388
# 12755           15637      14218
# 12757           13865      17309
# 12793           24874      42485
# 12807           31069      48013

# %% [markdown]
# ## Hitchcock Films

# %%
hitchcock_films = thriller[thriller['director'] == 'Alfred Hitchcock'].sort_values('avg_rating', ascending=False)

# %%
thriller[(thriller.year >= 1950) & (thriller.year <= 1960)].nlargest(15, 'avg_rating')
# Out:
#                          title  year               director  running_time  \
# 1                       Psycho  1960       Alfred Hitchcock           109
# 12215                  Le Trou  1960         Jacques Becker           132
# 12483            A Man Escaped  1956         Robert Bresson           101
# 12793              Rear Window  1954       Alfred Hitchcock           112
# 130     Sweet Smell of Success  1957  Alexander Mackendrick            97
# 12428        The Wages of Fear  1953  Henri-Georges Clouzot           153
# 12476        In a Lonely Place  1950           Nicholas Ray            94
# 12697  The Night of the Hunter  1955       Charles Laughton            93
# 12740       North by Northwest  1959       Alfred Hitchcock           136
# 12804                  Vertigo  1958       Alfred Hitchcock           128
# 12465      Anatomy of a Murder  1959         Otto Preminger           160
# 12565               Diabolique  1955  Henri-Georges Clouzot           117
# 12617            Touch of Evil  1958           Orson Welles            95
# 60        Strangers on a Train  1951       Alfred Hitchcock           101
# 104                   Godzilla  1954           Ishirō Honda            96
#
#         views   likes  avg_rating  half_star  one_star  one_half_star  \
# 1      323092  101066         4.3         85       229            167
# 12215    9685    3071         4.3          5         7              6
# 12483   21763    6531         4.3         11        16             23
# 12793  209305   68430         4.3         37       149            106
# 130     21043    6359         4.2          9        11             27
# 12428   18807    5430         4.2         14        26             29
# 12476   23904    7211         4.2         10        22             25
# 12697   57206   18460         4.2         33        90             84
# 12740  109221   28877         4.2         37        92            109
# 12804  207023   60166         4.2        138       322            303
# 12465   23738    5769         4.1          6        22             17
# 12565   29063    8001         4.1          8        21             37
# 12617   46770   11637         4.1         23        60             84
# 60      56887   13226         4.0         10        37             57
# 104     39659   10568         4.0         30        74             71
#
#        two_star  two_half_star  three_star  three_half_star  four_star  \
# 1          1161           1335       10300            13792      50704
# 12215        29             41         195              479       1805
# 12483       100            157         671             1339       4072
# 12793       674            978        5937            10078      33900
# 130         115            192         857             1508       3851
# 12428        92            164         614             1223       3365
# 12476       114            217        1008             1967       4934
# 12697       451            638        2377             3779       9171
# 12740       529            791        4393             7713      19964
# 12804      1378           1780        8715            12325      32198
# 12465       128            190        1016             1858       5041
# 12565       148            275        1305             2494       6630
# 12617       319            538        2302             3738       8568
# 60          267            591        3040             5831      12350
# 104         406            619        2697             3606       7199
#
#        four_half_star  five_star
# 1               33030      63548
# 12215            1897       1717
# 12483            3179       3765
# 12793           24874      42485
# 130              3185       3437
# 12428            3023       3087
# 12476            3393       3566
# 12697            7402      11402
# 12740           12284      14272
# 12804           20712      38301
# 12465            3262       2289
# 12565            3893       3064
# 12617            5697       5767
# 60               5627       4497
# 104              2911       4417

# %%
hitchcock_films[(hitchcock_films.year >= 1950) & (hitchcock_films.year <= 1960)]
# Out:
#                            title  year          director  running_time  \
# 1                         Psycho  1960  Alfred Hitchcock           109
# 12793                Rear Window  1954  Alfred Hitchcock           112
# 12740         North by Northwest  1959  Alfred Hitchcock           136
# 12804                    Vertigo  1958  Alfred Hitchcock           128
# 60          Strangers on a Train  1951  Alfred Hitchcock           101
# 12607          Dial M for Murder  1954  Alfred Hitchcock           105
# 12368  The Man Who Knew Too Much  1956  Alfred Hitchcock           120
# 117             To Catch a Thief  1955  Alfred Hitchcock           106
# 11455               Stage Fright  1950  Alfred Hitchcock           110
#
#         views   likes  avg_rating  half_star  one_star  one_half_star  \
# 1      323092  101066         4.3         85       229            167
# 12793  209305   68430         4.3         37       149            106
# 12740  109221   28877         4.2         37        92            109
# 12804  207023   60166         4.2        138       322            303
# 60      56887   13226         4.0         10        37             57
# 12607   56061   13233         4.0         19        38             48
# 12368   30820    5327         3.7         12        49             71
# 117     36872    7021         3.6         11        53             78
# 11455    5502     758         3.4          3        13             25
#
#        two_star  two_half_star  three_star  three_half_star  four_star  \
# 1          1161           1335       10300            13792      50704
# 12793       674            978        5937            10078      33900
# 12740       529            791        4393             7713      19964
# 12804      1378           1780        8715            12325      32198
# 60          267            591        3040             5831      12350
# 12607       259            497        2835             5485      12807
# 12368       343            732        3185             4696       5509
# 117         474           1036        4532             6012       6449
# 11455       110            269         935              979        653
#
#        four_half_star  five_star
# 1               33030      63548
# 12793           24874      42485
# 12740           12284      14272
# 12804           20712      38301
# 60               5627       4497
# 12607            6103       4072
# 12368            1451       1039
# 117              1538       1272
# 11455             108        113

# %%
thriller[(thriller.year >= 1950) & (thriller.year <= 1960)].avg_rating.mean()
# Out:
# 3.2890710382513704

# %%
hitchcock_films[(hitchcock_films.year >= 1950) & (hitchcock_films.year <= 1960)].avg_rating.mean()
# Out:
# 3.9666666666666663

# %%
thriller[(thriller.year >= 1910) & (thriller.year <= 1930)].shape
# Out:
# (30, 17)

# %%
(4.5 - thriller_rating_mean)/thriller_rating_std
# Out:
# 3.4888888888888885

# %%
(3.8 - thriller[(thriller.year >= 1950) & (thriller.year <= 1960)].avg_rating.mean())/thriller[(thriller.year >= 1950) & (thriller.year <= 1960)].avg_rating.std()
# Out:
# 1.3058497033987126

# %% [markdown]
# ## Likes,Views and Total Ratings

# %%
animation['total_ratings'] = animation.half_star + animation.one_star + animation.one_half_star + animation.two_star + animation.two_half_star + animation.three_star + animation.three_half_star + animation.four_star + animation.four_half_star + animation.five_star
horror['total_ratings'] = horror.half_star + horror.one_star + horror.one_half_star + horror.two_star + horror.two_half_star + horror.three_star + horror.three_half_star + horror.four_star + horror.four_half_star + horror.five_star
scifi['total_ratings'] = scifi.half_star + scifi.one_star + scifi.one_half_star + scifi.two_star + scifi.two_half_star + scifi.three_star + scifi.three_half_star + scifi.four_star + scifi.four_half_star + scifi.five_star
thriller['total_ratings'] = thriller.half_star + thriller.one_star + thriller.one_half_star + thriller.two_star + thriller.two_half_star + thriller.three_star + thriller.three_half_star + thriller.four_star + thriller.four_half_star + thriller.five_star

# %%
animation['like_to_views_ratio'] = animation.likes/animation.views
horror['like_to_views_ratio'] = horror.likes/horror.views
scifi['like_to_views_ratio'] = scifi.likes/scifi.views
thriller['like_to_views_ratio'] = thriller.likes/thriller.views

# %%
print('Like/Views Statistics: \n',
      f'Anim: μ ={animation.like_to_views_ratio.mean()}, \sigma ={animation.like_to_views_ratio.std()} \n',
      f'Horror: μ = {horror.like_to_views_ratio.mean()}, \sigma = {horror.like_to_views_ratio.std()} \n',
      f'Scifi: μ = {scifi.like_to_views_ratio.mean()}, \sigma = {scifi.like_to_views_ratio.std()} \n',
      f'Thriller: μ = {thriller.like_to_views_ratio.mean()}, \sigma = {thriller.like_to_views_ratio.std()}')
# Out:
# Like/Views Statistics:
#  Anim: μ =0.1431274809307327, \sigma =0.07831628606538732
#  Horror: μ = 0.12015481425408901, \sigma = 0.06981751160317613
#  Scifi: μ = 0.12804450639150405, \sigma = 0.07179931330465651
#  Thriller: μ = 0.11570558915885386, \sigma = 0.06876669831100726

# %%
animation['total_ratings_to_views_ratio'] = animation.total_ratings/animation.views
horror['total_ratings_to_views_ratio'] = horror.total_ratings/horror.views
scifi['total_ratings_to_views_ratio'] = scifi.total_ratings/scifi.views
thriller['total_ratings_to_views_ratio'] = thriller.total_ratings/thriller.views

# %%
print('Total_Ratings/Views Statistics: \n',
      f'Anim: μ ={animation.total_ratings_to_views_ratio.mean()}, \sigma ={animation.total_ratings_to_views_ratio.std()} \n',
      f'Horror: μ = {horror.total_ratings_to_views_ratio.mean()}, \sigma = {horror.total_ratings_to_views_ratio.std()} \n',
      f'Scifi: μ = {scifi.total_ratings_to_views_ratio.mean()}, \sigma = {scifi.total_ratings_to_views_ratio.std()} \n',
      f'Thriller: μ = {thriller.total_ratings_to_views_ratio.mean()}, \sigma = {thriller.total_ratings_to_views_ratio.std()}')
# Out:
# Total_Ratings/Views Statistics:
#  Anim: μ =0.5258850007907389, \sigma =0.12426410193125147
#  Horror: μ = 0.6311477864486709, \sigma = 0.0954864670431939
#  Scifi: μ = 0.5872224103065542, \sigma = 0.10232368580064084
#  Thriller: μ = 0.6161214185285863, \sigma = 0.09972676504289836

# %%
animation_skp = round(animation.like_to_views_ratio.skew(), 2)
horror_skp = round(horror.like_to_views_ratio.skew(), 2)
scifi_skp = round(scifi.like_to_views_ratio.skew(), 2)
thriller_skp = round(thriller.like_to_views_ratio.skew(), 2)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10), squeeze=True)
fig.suptitle('Like/Views Distribution', fontsize=25)

sns.distplot(animation.like_to_views_ratio, ax=axes[0,0], norm_hist=True,
             color='y', axlabel=False, label=f'Total of {animation_n_movies} Movies')
axes[0,0].set_title(f'Animation (μ = {round(animation.like_to_views_ratio.mean(),2)}, σ = {round(animation.like_to_views_ratio.std(), 2)}, Skp = {animation_skp})',
                    fontsize=20)
axes[0,0].legend(loc='upper right')

sns.distplot(horror.like_to_views_ratio, ax=axes[0,1], norm_hist=True,
             color='r', axlabel=False, label=f'Total of {horror_n_movies} Movies')
axes[0,1].set_title(f'Horror (μ = {round(horror.like_to_views_ratio.mean(), 2)}, σ = {round(horror.like_to_views_ratio.std(), 2)}, Skp = {horror_skp})',
                    fontsize=20)
axes[0,1].legend(loc='upper right')

sns.distplot(scifi.like_to_views_ratio, ax=axes[1,0], norm_hist=True,
             color='g', axlabel=False, label=f'Total of {scifi_n_movies} Movies')
axes[1,0].set_title(f'SciFi (μ = {round(scifi.like_to_views_ratio.mean(), 2)}, σ = {round(scifi.like_to_views_ratio.std(), 2)}, Skp = {scifi_skp})',
                    fontsize=20)
axes[1,0].legend(loc='upper right')

sns.distplot(thriller.like_to_views_ratio, ax=axes[1,1], norm_hist=True,
             color='k', axlabel=False, label=f'Total of {thriller_n_movies} Movies')
axes[1,1].set_title(f'Thriller (μ = {round(thriller.like_to_views_ratio.mean(), 2)}, σ = {round(thriller.like_to_views_ratio.std(), 2)}, Skp = {thriller_skp})',
                    fontsize=20)
axes[1,1].legend(loc='upper right')


plt.show()

# %%
animation_skp2 = round(animation.total_ratings_to_views_ratio.skew(), 2)
horror_skp2 = round(horror.total_ratings_to_views_ratio.skew(), 2)
scifi_skp2 = round(scifi.total_ratings_to_views_ratio.skew(), 2)
thriller_skp2 = round(thriller.total_ratings_to_views_ratio.skew(), 2)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10), squeeze=True)
fig.suptitle('Ratings/Views Distribution', fontsize=25)

sns.distplot(animation.total_ratings_to_views_ratio, ax=axes[0,0], norm_hist=True,
             color='y', axlabel=False, label=f'Total of {animation_n_movies} Movies')
axes[0,0].set_title(f'Animation (μ = {round(animation.total_ratings_to_views_ratio.mean(),2)}, σ = {round(animation.total_ratings_to_views_ratio.std(), 2)}, Skp = {animation_skp2})',
                    fontsize=20)
axes[0,0].legend(loc='upper right')

sns.distplot(horror.total_ratings_to_views_ratio, ax=axes[0,1], norm_hist=True,
             color='r', axlabel=False, label=f'Total of {horror_n_movies} Movies')
axes[0,1].set_title(f'Horror (μ = {round(horror.total_ratings_to_views_ratio.mean(), 2)}, σ = {round(horror.total_ratings_to_views_ratio.std(), 2)}, Skp = {horror_skp2})',
                    fontsize=20)
axes[0,1].legend(loc='upper left')

sns.distplot(scifi.total_ratings_to_views_ratio, ax=axes[1,0], norm_hist=True,
             color='g', axlabel=False, label=f'Total of {scifi_n_movies} Movies')
axes[1,0].set_title(f'SciFi (μ = {round(scifi.total_ratings_to_views_ratio.mean(), 2)}, σ = {round(scifi.total_ratings_to_views_ratio.std(), 2)}, Skp = {scifi_skp2})',
                    fontsize=20)
axes[1,0].legend(loc='upper left')

sns.distplot(thriller.total_ratings_to_views_ratio, ax=axes[1,1], norm_hist=True,
             color='k', axlabel=False, label=f'Total of {thriller_n_movies} Movies')
axes[1,1].set_title(f'Thriller (μ = {round(thriller.total_ratings_to_views_ratio.mean(), 2)}, σ = {round(thriller.total_ratings_to_views_ratio.std(), 2)}, Skp = {thriller_skp2})',
                    fontsize=20)
axes[1,1].legend(loc='upper left')

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10), squeeze=True)
fig.suptitle('Likes/Views vs Average Rating', fontsize=25)

sns.scatterplot(x='like_to_views_ratio', y='avg_rating', data = animation, ax=axes[0,0], color='m',
               alpha=0.4)
axes[0,0].set_title('Animation', fontsize=20)
axes[0,0].set_ylabel('Average Rating')
axes[0,0].set_xlabel('')
axes[0,0].set_ylim(0,5)
axes[0,0].set_xlim(0,0.6)


sns.scatterplot(x='like_to_views_ratio', y='avg_rating', data = horror, ax=axes[0,1], color='r',
               alpha=0.4)
axes[0,1].set_title('Horror', fontsize=20)
axes[0,1].set_xlabel('')
axes[0,1].set_ylabel('')
axes[0,1].set_ylim(0,5)
axes[0,1].set_xlim(0,0.6)


sns.scatterplot(x='like_to_views_ratio', y='avg_rating', data = scifi, ax=axes[1,0], color='g',
               alpha=0.4)
axes[1,0].set_title('SciFi', fontsize=20)
axes[1,0].set_ylabel('Average Rating')
axes[1,0].set_xlabel('Like to Views Ratio')
axes[1,0].set_ylim(0,5)
axes[1,0].set_xlim(0,0.6)


sns.scatterplot(x='like_to_views_ratio', y='avg_rating', data = thriller, ax=axes[1,1], color='k',
               alpha=0.4)
axes[1,1].set_title('Thriller', fontsize=20)
axes[1,1].set_xlabel('Like to Views Ratio')
axes[1,1].set_ylabel('')
axes[1,1].set_ylim(0,5)
axes[1,1].set_xlim(0,0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# ## Highest Rated Directors Per Genre

# %% [markdown]
# ## Animation

# %%
anim_grouped = animation.groupby('director')
n_movies = anim_grouped.size()

# %%
anim_directors = anim_grouped.mean()

# %%
anim_directors['n_movies'] = n_movies

# %%
anim_directors.describe()
# Out:
#               year  running_time          views          likes   avg_rating  \
# count  1808.000000   1808.000000    1808.000000    1808.000000  1808.000000
# mean   2003.519766     85.057226   15183.544213    2684.592412     3.091002
# std      14.649713     19.245674   54837.195937   12997.024582     0.482173
# min    1926.000000     50.000000      35.000000       0.000000     0.900000
# 25%    1997.000000     74.500000     150.000000      18.000000     2.800000
# 50%    2007.500000     84.000000     528.500000      68.833333     3.200000
# 75%    2014.000000     93.000000    3159.437500     440.500000     3.400000
# max    2020.000000    227.000000  549906.000000  232066.000000     4.400000
#
#          half_star     one_star  one_half_star      two_star  two_half_star  \
# count  1808.000000  1808.000000    1808.000000   1808.000000    1808.000000
# mean     78.540621   161.624834     147.110385    470.696386     512.013694
# std     330.024252   558.599541     472.990632   1441.540746    1505.905395
# min       0.000000     0.000000       0.000000      0.000000       0.000000
# 25%       1.000000     2.000000       3.000000      8.000000       8.958333
# 50%       5.000000    10.000000       9.000000     23.000000      27.000000
# 75%      26.000000    48.125000      53.000000    135.000000     172.000000
# max    6375.500000  7876.000000    6484.000000  16922.000000   13329.000000
#
#          three_star  three_half_star     four_star  four_half_star  \
# count   1808.000000      1808.000000   1808.000000     1808.000000
# mean    1383.982473      1129.289454   1611.208809      550.377019
# std     4472.285462      4062.867038   7484.660224     3269.374119
# min        0.000000         0.000000      0.000000        0.000000
# 25%       16.375000        10.000000      9.000000        2.000000
# 50%       55.533333        39.000000     34.000000        8.000000
# 75%      352.750000       254.125000    237.250000       54.100000
# max    40274.000000     39676.000000  85623.000000    71034.000000
#
#            five_star  total_ratings  like_to_views_ratio  \
# count    1808.000000    1808.000000          1808.000000
# mean      909.152123    6953.995798             0.139831
# std      6097.335594   26026.338161             0.076846
# min         0.000000      24.000000             0.000000
# 25%         3.500000      80.000000             0.083266
# 50%        15.000000     279.500000             0.127250
# 75%        88.250000    1679.375000             0.183437
# max    151015.000000  347802.000000             0.492082
#
#        total_ratings_to_views_ratio     n_movies
# count                   1808.000000  1808.000000
# mean                       0.529891     1.528761
# std                        0.124920     1.489774
# min                        0.208333     1.000000
# 25%                        0.438548     1.000000
# 50%                        0.532184     1.000000
# 75%                        0.618587     1.000000
# max                        0.867470    25.000000

# %%
anim_top15_dirs = anim_directors[anim_directors.n_movies > anim_directors.n_movies.quantile(0.75)].nlargest(15, ['avg_rating', 'n_movies', 'like_to_views_ratio'])

# %%
anim_top15_dirs = anim_top15_dirs[['avg_rating', 'n_movies', 'running_time', 'views', 'likes', 'like_to_views_ratio', 'total_ratings_to_views_ratio' ]].round(2)
anim_top15_dirs
# Out:
#                                avg_rating  n_movies  running_time      views  \
# director
# Satoshi Kon                          4.10         4         87.50   55095.00
# Andrew Stanton                       4.10         2         99.00  534336.00
# John Lasseter                        4.10         2         86.50  499319.00
# Hayao Miyazaki                       4.06        11        111.27  158321.73
# Jarrad Wright                        4.00         2         60.50     154.00
# Wes Anderson                         4.00         2         94.00  256293.50
# Brad Bird                            3.97         3        106.33  373112.00
# Hideaki Anno,Kazuya Tsurumaki        3.95         2        141.00   27346.50
# Pete Docter                          3.95         2         93.50  530608.00
# Cole Sanchez,Elizabeth Ito           3.90         2         89.00    1299.50
# Marcell Jankovics                    3.87         3        105.00     842.67
# Naoko Yamada                         3.85         4        103.25   14164.75
# Chris Sanders,Dean DeBlois           3.85         2         92.50  270072.00
# Akiyuki Shinbo,Tatsuya Oishi         3.83         3         70.33    3313.00
# Patrick Bokanowski                   3.80         2         66.00     568.50
#
#                                    likes  like_to_views_ratio  \
# director
# Satoshi Kon                     18721.25                 0.33
# Andrew Stanton                 137109.50                 0.26
# John Lasseter                  116234.50                 0.23
# Hayao Miyazaki                  53697.18                 0.31
# Jarrad Wright                      54.50                 0.36
# Wes Anderson                    85534.00                 0.33
# Brad Bird                       97922.67                 0.27
# Hideaki Anno,Kazuya Tsurumaki   10041.00                 0.28
# Pete Docter                    140520.50                 0.26
# Cole Sanchez,Elizabeth Ito        305.50                 0.24
# Marcell Jankovics                 275.67                 0.31
# Naoko Yamada                     4886.25                 0.31
# Chris Sanders,Dean DeBlois      56797.50                 0.21
# Akiyuki Shinbo,Tatsuya Oishi      830.67                 0.25
# Patrick Bokanowski                156.00                 0.26
#
#                                total_ratings_to_views_ratio
# director
# Satoshi Kon                                            0.60
# Andrew Stanton                                         0.45
# John Lasseter                                          0.43
# Hayao Miyazaki                                         0.57
# Jarrad Wright                                          0.73
# Wes Anderson                                           0.63
# Brad Bird                                              0.51
# Hideaki Anno,Kazuya Tsurumaki                          0.52
# Pete Docter                                            0.48
# Cole Sanchez,Elizabeth Ito                             0.50
# Marcell Jankovics                                      0.58
# Naoko Yamada                                           0.66
# Chris Sanders,Dean DeBlois                             0.42
# Akiyuki Shinbo,Tatsuya Oishi                           0.66
# Patrick Bokanowski                                     0.57

# %% [markdown]
# ## Sci-Fi

# %%
scifi_grouped = scifi.groupby('director')
scifi_n_movies = scifi_grouped.size()

# %%
scifi_directors = scifi_grouped.mean()

# %%
scifi_directors['n_movies'] = scifi_n_movies

# %%
scifi_directors.describe()
# Out:
#               year  running_time          views          likes   avg_rating  \
# count  3430.000000   3430.000000    3430.000000    3430.000000  3430.000000
# mean   1996.871354     94.492865   10490.555044    2005.896286     2.838993
# std      19.679625     19.880049   43335.687205   11614.394747     0.475557
# min    1916.000000     50.000000      37.000000       0.000000     1.200000
# 25%    1986.000000     85.000000     124.000000      12.000000     2.500000
# 50%    2003.000000     91.500000     363.000000      44.000000     2.900000
# 75%    2013.000000    101.000000    2059.500000     255.250000     3.200000
# max    2020.000000    240.000000  650979.500000  237693.000000     4.400000
#
#           half_star      one_star  one_half_star      two_star  two_half_star  \
# count   3430.000000   3430.000000    3430.000000   3430.000000    3430.000000
# mean     105.523958    221.675972     203.902987    549.193083     540.416317
# std      583.492943   1036.711378     812.293439   2093.702018    1932.340696
# min        0.000000      0.000000       0.000000      0.000000       0.000000
# 25%        2.000000      5.000000       5.000000     10.000000       9.000000
# 50%        8.000000     15.000000      15.500000     32.000000      27.750000
# 75%       30.729167     64.000000      63.916667    145.500000     151.000000
# max    26627.000000  41716.000000   25062.000000  49076.000000   26754.000000
#
#          three_star  three_half_star      four_star  four_half_star  \
# count   3430.000000      3430.000000    3430.000000     3430.000000
# mean    1166.176640       903.550149    1149.016310      396.992402
# std     4614.061294      3900.616237    6380.651587     2861.192898
# min        0.000000         0.000000       0.000000        0.000000
# 25%       13.000000         6.000000       4.000000        1.000000
# 50%       43.000000        23.000000      16.000000        3.000000
# 75%      268.750000       162.833333     118.000000       24.000000
# max    67523.000000     58170.000000  107842.500000    70990.000000
#
#            five_star  total_ratings  like_to_views_ratio  \
# count    3430.000000    3430.000000          3430.000000
# mean      576.860740    5813.308558             0.124057
# std      5057.126156   24934.977517             0.068528
# min         0.000000      22.000000             0.000000
# 25%         1.000000      73.000000             0.072335
# 50%         5.000000     225.500000             0.113191
# 75%        33.000000    1185.750000             0.164498
# max    150869.000000  379739.500000             0.563636
#
#        total_ratings_to_views_ratio     n_movies
# count                   3430.000000  3430.000000
# mean                       0.593757     1.460933
# std                        0.102987     1.334455
# min                        0.058524     1.000000
# 25%                        0.524601     1.000000
# 50%                        0.592380     1.000000
# 75%                        0.660676     1.000000
# max                        0.947826    24.000000

# %%
scifi_top15_dirs = scifi_directors[scifi_directors.n_movies > scifi_directors.n_movies.quantile(0.75)].nlargest(15, ['avg_rating', 'n_movies', 'like_to_views_ratio'])

# %%
scifi_top15_dirs = scifi_top15_dirs[['avg_rating', 'n_movies', 'running_time', 'views', 'likes', 'like_to_views_ratio', 'total_ratings_to_views_ratio' ]].round(2)
scifi_top15_dirs
# Out:
#                                avg_rating  n_movies  running_time      views  \
# director
# Andrey Tarkovsky                     4.30         2        164.50   71350.00
# Stanley Kubrick                      4.25         2        143.00  344594.50
# Christopher Nolan                    4.15         2        158.50  650979.50
# Denis Villeneuve                     4.10         2        139.50  439005.50
# Hideaki Anno,Kazuya Tsurumaki        3.95         2        141.00   27303.00
# Alfonso Cuarón                       3.90         2        100.00  322039.00
# James Whale                          3.85         2         71.00   40230.00
# George Miller                        3.83         3        102.67  255006.33
# James Cameron                        3.82         5        140.40  261365.00
# Hiroyuki Imaishi                     3.80         3         96.33    4236.33
# Konstantin Lopushansky               3.80         3        106.67    1472.67
# Fritz Lang                           3.80         3        135.67   31408.67
# Anthony Russo,Joe Russo              3.80         4        153.25  502518.00
# Alex Garland                         3.80         2        111.50  355451.00
# Genndy Tartakovsky                   3.80         2         70.00    3424.50
#
#                                    likes  like_to_views_ratio  \
# director
# Andrey Tarkovsky                23566.00                 0.33
# Stanley Kubrick                112199.50                 0.33
# Christopher Nolan              237693.00                 0.37
# Denis Villeneuve               163868.00                 0.37
# Hideaki Anno,Kazuya Tsurumaki   10027.50                 0.28
# Alfonso Cuarón                  81384.50                 0.27
# James Whale                      9493.00                 0.24
# George Miller                   91602.00                 0.28
# James Cameron                   57655.00                 0.23
# Hiroyuki Imaishi                 1465.67                 0.31
# Konstantin Lopushansky            416.33                 0.26
# Fritz Lang                       8058.33                 0.22
# Anthony Russo,Joe Russo        156027.00                 0.31
# Alex Garland                   109871.50                 0.30
# Genndy Tartakovsky                607.00                 0.17
#
#                                total_ratings_to_views_ratio
# director
# Andrey Tarkovsky                                       0.61
# Stanley Kubrick                                        0.56
# Christopher Nolan                                      0.59
# Denis Villeneuve                                       0.67
# Hideaki Anno,Kazuya Tsurumaki                          0.52
# Alfonso Cuarón                                         0.57
# James Whale                                            0.56
# George Miller                                          0.57
# James Cameron                                          0.51
# Hiroyuki Imaishi                                       0.64
# Konstantin Lopushansky                                 0.63
# Fritz Lang                                             0.52
# Anthony Russo,Joe Russo                                0.61
# Alex Garland                                           0.66
# Genndy Tartakovsky                                     0.48

# %% [markdown]
# ## Thriller

# %%
thriller_grouped = thriller.groupby('director')
thriller_n_movies = thriller_grouped.size()

# %%
thriller_directors = thriller_grouped.mean()

# %%
thriller_directors['n_movies'] = thriller_n_movies

# %%
thriller_directors.describe()
# Out:
#               year  running_time          views          likes   avg_rating  \
# count  7415.000000   7415.000000    7415.000000    7415.000000  7415.000000
# mean   2001.500529     98.876350    4874.001797     901.947882     2.903763
# std      18.819958     17.620504   22351.380048    6124.265198     0.403700
# min    1913.000000     50.000000      33.000000       0.000000     1.100000
# 25%    1994.333333     89.000000     104.000000       9.000000     2.681667
# 50%    2009.000000     95.000000     290.000000      30.000000     2.900000
# 75%    2015.000000    105.500000    1268.666667     155.000000     3.200000
# max    2020.000000    232.000000  529652.000000  189045.000000     4.400000
#
#          half_star      one_star  one_half_star      two_star  two_half_star  \
# count  7415.000000   7415.000000    7415.000000   7415.000000    7415.000000
# mean     46.293748     95.367976      92.972750    246.847356     261.493330
# std     226.018727    395.260069     344.006630    907.996723     921.709878
# min       0.000000      0.000000       0.000000      0.000000       0.000000
# 25%       1.000000      4.000000       4.000000     10.000000       9.500000
# 50%       5.000000     10.000000      10.333333     24.500000      26.000000
# 75%      18.000000     34.000000      36.000000     92.291667     100.238095
# max    9777.000000  11929.000000    7487.000000  27060.000000   25535.000000
#
#          three_star  three_half_star      four_star  four_half_star  \
# count   7415.000000      7415.000000    7415.000000     7415.000000
# mean     564.138861       491.164940     609.210290      218.492011
# std     2263.944495      2268.792783    3944.290362     1857.521138
# min        0.000000         0.000000       0.000000        0.000000
# 25%       13.000000         6.000000       3.000000        0.354167
# 50%       40.666667        23.000000      15.000000        3.000000
# 75%      186.785714       128.000000      91.000000       17.000000
# max    58742.000000     53357.000000  107541.000000    55446.000000
#
#           five_star  total_ratings  like_to_views_ratio  \
# count   7415.000000    7415.000000          7415.000000
# mean     246.691702    2872.672963             0.111067
# std     2551.839835   13764.675145             0.065072
# min        0.000000      12.000000             0.000000
# 25%        1.000000      65.000000             0.063140
# 50%        3.000000     180.000000             0.100329
# 75%       18.000000     796.750000             0.147273
# max    87311.333333  403689.000000             0.757576
#
#        total_ratings_to_views_ratio     n_movies
# count                   7415.000000  7415.000000
# mean                       0.627036     1.679029
# std                        0.098510     1.681397
# min                        0.102151     1.000000
# 25%                        0.562500     1.000000
# 50%                        0.623371     1.000000
# 75%                        0.693694     2.000000
# max                        0.969697    37.000000

# %%
thriller_top15_dirs = thriller_directors[thriller_directors.n_movies > thriller_directors.n_movies.quantile(0.75)].nlargest(15, ['avg_rating', 'n_movies', 'like_to_views_ratio'])

# %%
thriller_top15_dirs = thriller_top15_dirs[['avg_rating', 'n_movies', 'running_time', 'views', 'likes', 'like_to_views_ratio', 'total_ratings_to_views_ratio' ]].round(2)
thriller_top15_dirs
# Out:
#                           avg_rating  n_movies  running_time      views  \
# director
# Bong Joon-ho                    4.30         3        131.00  221043.00
# Quentin Tarantino               3.99         7        138.71  398019.14
# Akira Kurosawa                  3.94         5        116.60   19496.20
# Henri-Georges Clouzot           3.92         4        111.50   13830.25
# David Lynch                     3.92         5        141.00  107665.00
# Denis Villeneuve                3.90         3        122.00  213827.00
# Jean-Pierre Melville            3.89         7        118.57   13699.43
# Christopher Nolan               3.88         6        124.33  338241.33
# Rainer Werner Fassbinder        3.87         3        141.67    4506.67
# James Cameron                   3.86         5        136.20  177956.60
# Shunya Ito                      3.83         3         89.67    3305.00
# Fred Zinnemann                  3.83         3        103.33   14727.67
# David Fincher                   3.83         7        142.43  291233.43
# Stanley Kubrick                 3.82         4        114.00  195119.00
# Park Chan-wook                  3.79         8        118.25   70206.38
#
#                               likes  like_to_views_ratio  \
# director
# Bong Joon-ho              108370.33                 0.39
# Quentin Tarantino         136767.43                 0.31
# Akira Kurosawa              6029.60                 0.27
# Henri-Georges Clouzot       3725.25                 0.24
# David Lynch                31679.00                 0.27
# Denis Villeneuve           61517.33                 0.28
# Jean-Pierre Melville        3968.00                 0.25
# Christopher Nolan         105767.17                 0.26
# Rainer Werner Fassbinder    1187.33                 0.25
# James Cameron              45474.20                 0.23
# Shunya Ito                  1093.33                 0.32
# Fred Zinnemann              3088.33                 0.21
# David Fincher              78768.29                 0.24
# Stanley Kubrick            63968.75                 0.25
# Park Chan-wook             22480.12                 0.25
#
#                           total_ratings_to_views_ratio
# director
# Bong Joon-ho                                      0.73
# Quentin Tarantino                                 0.60
# Akira Kurosawa                                    0.63
# Henri-Georges Clouzot                             0.62
# David Lynch                                       0.58
# Denis Villeneuve                                  0.65
# Jean-Pierre Melville                              0.65
# Christopher Nolan                                 0.56
# Rainer Werner Fassbinder                          0.63
# James Cameron                                     0.51
# Shunya Ito                                        0.68
# Fred Zinnemann                                    0.60
# David Fincher                                     0.54
# Stanley Kubrick                                   0.59
# Park Chan-wook                                    0.64

# %% [markdown]
# ## Cluster Analysis

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ## Animation PCA

# %%
anim_pipeline = Pipeline([('scaler', StandardScaler()),
                         ('pca', PCA(n_components=0.94, random_state=69))], verbose=True)

# %%
anim_features = animation[['avg_rating', 'running_time', 'like_to_views_ratio', 'total_ratings_to_views_ratio']]

# %%
anim_pipeline.fit(anim_features)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing pca, total=   0.0s
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', PCA(n_components=0.94, random_state=69))],
#          verbose=True)

# %%
anim_pipeline['pca'].explained_variance_ratio_
# Out:
# array([0.490655  , 0.24299788, 0.21543449])

# %%
anim_coefs = pd.DataFrame(anim_pipeline['pca'].components_, columns=anim_features.columns, index=['PC1', 'PC2', 'PC3'])
anim_coefs
# Out:
#      avg_rating  running_time  like_to_views_ratio  \
# PC1    0.584119      0.279931             0.658281
# PC2   -0.456838      0.687134            -0.195623
# PC3    0.233381      0.670368            -0.084736
#
#      total_ratings_to_views_ratio
# PC1                      0.383549
# PC2                      0.529979
# PC3                     -0.699257

# %%
anim_features_3d = anim_pipeline.transform(anim_features)

# %%
anim_reduced = pd.DataFrame(anim_features_3d, columns=anim_coefs.index, index=anim_features.index)

# %%
anim_reduced
# Out:
#            PC1       PC2       PC3
# 0     5.551399 -0.173259  0.037565
# 1     0.627905 -0.085587  0.604304
# 2     1.102763 -0.318244  0.926592
# 3     1.552283 -0.799622  1.163586
# 4     1.086719 -0.644339  1.196931
# ...        ...       ...       ...
# 8118  2.140225  0.668073  0.683013
# 8119  4.559057 -0.491038  1.351425
# 8120  2.361729 -0.756415  0.421116
# 8121  3.819937 -0.514897  0.270416
# 8122  2.080634 -1.583065  0.967811
#
# [2764 rows x 3 columns]

# %% [markdown]
# ## Horror PCA

# %%
horror_pipeline = Pipeline([('scaler', StandardScaler()),
                            ('pca', PCA(n_components=0.93, random_state=69))], verbose=True)

# %%
horror_features = horror[['avg_rating', 'running_time', 'like_to_views_ratio', 'total_ratings_to_views_ratio']]

# %%
horror_pipeline.fit(horror_features)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing pca, total=   0.0s
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', PCA(n_components=0.93, random_state=69))],
#          verbose=True)

# %%
horror_pipeline['pca'].explained_variance_ratio_
# Out:
# array([0.43009477, 0.27750585, 0.22546961])

# %%
horror_coefs = pd.DataFrame(horror_pipeline['pca'].components_, columns=horror_features.columns, index=['PC1', 'PC2', 'PC3'])
horror_coefs
# Out:
#      avg_rating  running_time  like_to_views_ratio  \
# PC1    0.698342      0.162227             0.694600
# PC2    0.100251      0.623650            -0.181971
# PC3   -0.155736      0.760161            -0.074554
#
#      total_ratings_to_views_ratio
# PC1                      0.059428
# PC2                     -0.753590
# PC3                      0.626373

# %%
horror_features_3d = horror_pipeline.transform(horror_features)

# %%
horror_reduced = pd.DataFrame(horror_features_3d, columns=horror_coefs.index, index=horror_features.index)

# %%
horror_reduced
# Out:
#             PC1       PC2       PC3
# 0      5.335896 -0.257858  0.190462
# 1      2.247709  0.710913 -1.291127
# 2      4.072782  1.448224  3.497359
# 3      3.434207  0.374593 -0.973080
# 4      4.396847  2.362142  1.380558
# ...         ...       ...       ...
# 11047  3.712308 -0.062510  1.542456
# 11048  4.724670  0.432459  1.918753
# 11049  5.376177  2.425394  1.692168
# 11050  4.625086  0.943230  3.408248
# 11051  5.072297 -0.955048  1.343737
#
# [9878 rows x 3 columns]

# %% [markdown]
# ## Sci-Fi PCA

# %%
scifi_pipeline = Pipeline([('scaler', StandardScaler()),
                            ('pca', PCA(n_components=0.93, random_state=69))], verbose=True)

scifi_features = scifi[['avg_rating', 'running_time', 'like_to_views_ratio', 'total_ratings_to_views_ratio']]

# %%
scifi_pipeline.fit(scifi_features)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing pca, total=   0.0s
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', PCA(n_components=0.93, random_state=69))],
#          verbose=True)

# %%
scifi_pipeline['pca'].explained_variance_ratio_
# Out:
# array([0.44330263, 0.27758038, 0.21714656])

# %%
scifi_coefs = pd.DataFrame(scifi_pipeline['pca'].components_, columns=scifi_features.columns, index=['PC1', 'PC2', 'PC3'])
scifi_coefs
# Out:
#      avg_rating  running_time  like_to_views_ratio  \
# PC1    0.692704      0.243512             0.678672
# PC2    0.005123      0.571512            -0.229284
# PC3   -0.180325      0.782410            -0.082450
#
#      total_ratings_to_views_ratio
# PC1                     -0.016360
# PC2                     -0.787894
# PC3                      0.590355

# %%
scifi_features_3d = scifi_pipeline.transform(scifi_features)

# %%
scifi_reduced = pd.DataFrame(scifi_features_3d, columns=scifi_coefs.index, index=scifi_features.index)

# %%
scifi_reduced
# Out:
#            PC1       PC2       PC3
# 0     5.776852 -1.693009  0.742748
# 1     4.274548  0.079607 -0.028665
# 2     1.764879 -0.311187  1.462110
# 3     3.114686  1.089483  0.772266
# 4     2.913478  0.667823  1.191225
# ...        ...       ...       ...
# 5822  4.552856  0.852221  3.264730
# 5823  4.674257  0.925199  1.133296
# 5824  3.350330  0.079292  1.291887
# 5825  4.209980  0.298126  1.786649
# 5826  4.834803 -0.449191  0.391313
#
# [5011 rows x 3 columns]

# %% [markdown]
# ## Thriller PCA

# %%
thriller_pipeline = Pipeline([('scaler', StandardScaler()),
                            ('pca', PCA(n_components=0.93, random_state=69))], verbose=True)

thriller_features = thriller[['avg_rating', 'running_time', 'like_to_views_ratio', 'total_ratings_to_views_ratio']]

# %%
thriller_pipeline.fit(thriller_features)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing pca, total=   0.0s
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', PCA(n_components=0.93, random_state=69))],
#          verbose=True)

# %%
thriller_pipeline['pca'].explained_variance_ratio_
# Out:
# array([0.45180715, 0.29412394, 0.19057505])

# %%
thriller_coefs = pd.DataFrame(thriller_pipeline['pca'].components_, columns=thriller_features.columns, index=['PC1', 'PC2', 'PC3'])
thriller_coefs
# Out:
#      avg_rating  running_time  like_to_views_ratio  \
# PC1    0.669062      0.280534             0.674125
# PC2    0.084669      0.613755            -0.182472
# PC3   -0.294567      0.737225            -0.136281
#
#      total_ratings_to_views_ratio
# PC1                      0.138608
# PC2                     -0.763439
# PC3                      0.592585

# %%
thriller_features_3d = thriller_pipeline.transform(thriller_features)

# %%
thriller_reduced = pd.DataFrame(thriller_features_3d, columns=thriller_coefs.index, index=thriller_features.index)

# %%
thriller_reduced
# Out:
#             PC1       PC2       PC3
# 0      7.256153 -1.089609  0.453294
# 1      4.007393  0.614750 -1.394495
# 2      4.003343  1.871027  0.995235
# 3      3.131066 -0.342389 -0.856696
# 4      3.708962 -0.022767 -1.481145
# ...         ...       ...       ...
# 12831  4.991042 -0.916667 -0.907437
# 12832  4.874538  0.457302  2.176331
# 12833  5.871441  1.493209  0.349747
# 12834  4.194466 -0.879206  0.675714
# 12835  5.716070  1.543426  0.228033
#
# [12450 rows x 3 columns]

# %% [markdown]
# ## Animation clustering

# %%
from sklearn.metrics import silhouette_score

# %%
anim_kmeans_per_k = [KMeans(n_clusters=k, random_state=69).fit(anim_reduced) for k in range(1,11)]

anim_inertias = [model.inertia_ for model in anim_kmeans_per_k]

# %%
plt.figure(figsize=(9,5))
plt.plot(range(1, 11), anim_inertias, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.xlim([0, 11])
plt.show()

# %%
anim_silhouette_scores = [silhouette_score(anim_reduced, model.labels_) for model in anim_kmeans_per_k[1:]]
anim_silhouette_scores
# Out:
# [0.302737269916155,
#  0.26269486904341577,
#  0.26806400228224414,
#  0.25562064765433384,
#  0.26135556887469596,
#  0.26167955489261985,
#  0.2581493476379055,
#  0.25036686801861713,
#  0.2535066099507489]

# %%
plt.figure(figsize=(9, 5))
plt.plot(range(2, 11), anim_silhouette_scores, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()

# %%
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter
import matplotlib as mpl

# %%
plt.figure(figsize=(15, 10))
n = 0
for k in (2, 3, 4, 7):
    n +=1
    plt.subplot(2, 2, n)
    
    y_pred = anim_kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(anim_reduced, y_pred)

    padding = len(anim_reduced) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (2, 4):
        plt.ylabel("Cluster")
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        
    if k in (4, 7):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=anim_silhouette_scores[k], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %%
horror_kmeans_per_k = [KMeans(n_clusters=k, random_state=69).fit(horror_reduced) for k in range(1,11)]

# %%
horror_inertias = [model.inertia_ for model in horror_kmeans_per_k]

# %%
plt.figure(figsize=(9,5))
plt.plot(range(1, 11), horror_inertias, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.xlim([0, 11])
plt.show()

# %%
horror_silhouette_scores = [silhouette_score(horror_reduced, model.labels_) for model in horror_kmeans_per_k[1:]]
horror_silhouette_scores
# Out:
# [0.2911117856653687,
#  0.2506353831145447,
#  0.2640872594727399,
#  0.24477721963957316,
#  0.23625239333214001,
#  0.2366268527841158,
#  0.23618363621719335,
#  0.22346321322016416,
#  0.2264424190999374]

# %%
plt.figure(figsize=(9, 5))
plt.plot(range(2, 11), horror_silhouette_scores, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 10))
n = 0
for k in (2, 3, 4, 7):
    n +=1
    plt.subplot(2, 2, n)
    
    y_pred = horror_kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(horror_reduced, y_pred)

    padding = len(horror_reduced) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (2, 4):
        plt.ylabel("Cluster")
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        
    if k in (4, 7):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=horror_silhouette_scores[k], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %%
thriller_kmeans_per_k = [KMeans(n_clusters=k, random_state=69).fit(thriller_reduced) for k in range(1,11)]

thriller_inertias = [model.inertia_ for model in thriller_kmeans_per_k]

# %%
plt.figure(figsize=(9,5))
plt.plot(range(1, 11), thriller_inertias, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.xlim([0, 11])
plt.show()

# %%
thriller_silhouette_scores = [silhouette_score(thriller_reduced, model.labels_) for model in thriller_kmeans_per_k[1:]]
thriller_silhouette_scores
# Out:
# [0.29742517371965965,
#  0.25443020504004676,
#  0.2678357067755673,
#  0.2548163302601666,
#  0.23684635069581295,
#  0.23614186367524226,
#  0.23682162559343256,
#  0.22849312751804804,
#  0.23351857257557546]

# %%
plt.figure(figsize=(9, 5))
plt.plot(range(2, 11), thriller_silhouette_scores, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 10))
n = 0
for k in (2, 3, 4, 7):
    n +=1
    plt.subplot(2, 2, n)
    
    y_pred = thriller_kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(thriller_reduced, y_pred)

    padding = len(thriller_reduced) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (2, 4):
        plt.ylabel("Cluster")
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        
    if k in (4, 7):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=thriller_silhouette_scores[k], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %%
scifi_kmeans_per_k = [KMeans(n_clusters=k, random_state=69).fit(scifi_reduced) for k in range(1,11)]

scifi_inertias = [model.inertia_ for model in scifi_kmeans_per_k]

# %%
plt.figure(figsize=(9,5))
plt.plot(range(1, 11), scifi_inertias, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.xlim([0, 11])
plt.show()

# %%
scifi_silhouette_scores = [silhouette_score(scifi_reduced, model.labels_) for model in scifi_kmeans_per_k[1:]]
scifi_silhouette_scores
# Out:
# [0.2947600111843814,
#  0.24905106055293919,
#  0.26242113876776035,
#  0.2464224165382736,
#  0.23458460330376352,
#  0.23370229368972958,
#  0.2268842118508836,
#  0.23398696764185967,
#  0.2395120047976993]

# %%
plt.figure(figsize=(9, 5))
plt.plot(range(2, 11), scifi_silhouette_scores, "yo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 10))
n = 0
for k in (2, 3, 4, 7):
    n +=1
    plt.subplot(2, 2, n)
    
    y_pred = scifi_kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(scifi_reduced, y_pred)

    padding = len(scifi_reduced) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (2, 4):
        plt.ylabel("Cluster")
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        
    if k in (4, 7):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=scifi_silhouette_scores[k], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)


plt.show()

# %% [markdown]
# ## We are choosing K as 3

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
anim_clusters = anim_kmeans_per_k[2]

# %%
animation['cluster'] = anim_clusters.labels_

# %%
fig = plt.figure(figsize=(10,7))

ax = fig.add_subplot(111, projection="3d")
ax.set_position([0, 0, 0.95, 1])
# Plotting Cluster 0
x_0 = anim_reduced[animation.cluster == 0].PC1
y_0 = anim_reduced[animation.cluster == 0].PC2
z_0 = anim_reduced[animation.cluster == 0].PC3
ax.scatter(x_0, y_0, z_0, label='Cluster 0', marker='o', alpha=0.5)

# Plotting Cluster 1
x_1 = anim_reduced[animation.cluster == 1].PC1
y_1 = anim_reduced[animation.cluster == 1].PC2
z_1 = anim_reduced[animation.cluster == 1].PC3
ax.scatter(x_1, y_1, z_1, label='Cluster 1', marker='o', alpha=0.5)

# Plotting Cluster 2
x_2 = anim_reduced[animation.cluster == 2].PC1
y_2 = anim_reduced[animation.cluster == 2].PC2
z_2 = anim_reduced[animation.cluster == 2].PC3
ax.scatter(x_2, y_2, z_2, label='Cluster 2', marker='o', alpha=0.5)




ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('Animation: Clusters')

ax.view_init(15, 25)

plt.legend()

plt.show()

# %%
horror_clusters = horror_kmeans_per_k[2]

horror['cluster'] = horror_clusters.labels_


fig = plt.figure(figsize=(10,7))

ax = fig.add_subplot(111, projection="3d")
ax.set_position([0, 0, 0.95, 1])
# Plotting Cluster 0
x_0 = horror_reduced[horror.cluster == 0].PC1
y_0 = horror_reduced[horror.cluster == 0].PC2
z_0 = horror_reduced[horror.cluster == 0].PC3
ax.scatter(x_0, y_0, z_0, label='Cluster 0', marker='o', alpha=0.5)

# Plotting Cluster 1
x_1 = horror_reduced[horror.cluster == 1].PC1
y_1 = horror_reduced[horror.cluster == 1].PC2
z_1 = horror_reduced[horror.cluster == 1].PC3
ax.scatter(x_1, y_1, z_1, label='Cluster 1', marker='o', alpha=0.5)

# Plotting Cluster 2
x_2 = horror_reduced[horror.cluster == 2].PC1
y_2 = horror_reduced[horror.cluster == 2].PC2
z_2 = horror_reduced[horror.cluster == 2].PC3
ax.scatter(x_2, y_2, z_2, label='Cluster 2', marker='o', alpha=0.5)




ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('Horror: Clusters')

ax.view_init(15, 25)

plt.legend()

plt.show()

# %%
thriller_clusters = thriller_kmeans_per_k[2]

thriller['cluster'] = thriller_clusters.labels_


fig = plt.figure(figsize=(10,7))

ax = fig.add_subplot(111, projection="3d")
ax.set_position([0, 0, 0.95, 1])
# Plotting Cluster 0
x_0 = thriller_reduced[thriller.cluster == 0].PC1
y_0 = thriller_reduced[thriller.cluster == 0].PC2
z_0 = thriller_reduced[thriller.cluster == 0].PC3
ax.scatter(x_0, y_0, z_0, label='Cluster 0', marker='o', alpha=0.5)

# Plotting Cluster 1
x_1 = thriller_reduced[thriller.cluster == 1].PC1
y_1 = thriller_reduced[thriller.cluster == 1].PC2
z_1 = thriller_reduced[thriller.cluster == 1].PC3
ax.scatter(x_1, y_1, z_1, label='Cluster 1', marker='o', alpha=0.5)

# Plotting Cluster 2
x_2 = thriller_reduced[thriller.cluster == 2].PC1
y_2 = thriller_reduced[thriller.cluster == 2].PC2
z_2 = thriller_reduced[thriller.cluster == 2].PC3
ax.scatter(x_2, y_2, z_2, label='Cluster 2', marker='o', alpha=0.5)




ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('Thriller: Clusters')

ax.view_init(15, 25)

plt.legend()

plt.show()

# %%
scifi_clusters = scifi_kmeans_per_k[2]

scifi['cluster'] = scifi_clusters.labels_


fig = plt.figure(figsize=(10,7))

ax = fig.add_subplot(111, projection="3d")
ax.set_position([0, 0, 0.95, 1])
# Plotting Cluster 0
x_0 = scifi_reduced[scifi.cluster == 0].PC1
y_0 = scifi_reduced[scifi.cluster == 0].PC2
z_0 = scifi_reduced[scifi.cluster == 0].PC3
ax.scatter(x_0, y_0, z_0, label='Cluster 0', marker='o', alpha=0.5)

# Plotting Cluster 1
x_1 = scifi_reduced[scifi.cluster == 1].PC1
y_1 = scifi_reduced[scifi.cluster == 1].PC2
z_1 = scifi_reduced[scifi.cluster == 1].PC3
ax.scatter(x_1, y_1, z_1, label='Cluster 1', marker='o', alpha=0.5)

# Plotting Cluster 2
x_2 = scifi_reduced[scifi.cluster == 2].PC1
y_2 = scifi_reduced[scifi.cluster == 2].PC2
z_2 = scifi_reduced[scifi.cluster == 2].PC3
ax.scatter(x_2, y_2, z_2, label='Cluster 2', marker='o', alpha=0.5)




ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('Scifi: Clusters')

ax.view_init(15, 25)

plt.legend()

plt.show()
